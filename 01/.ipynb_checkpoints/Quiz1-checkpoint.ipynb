# %% [markdown]
# - Quiz 1
# >홍길동 씨의 주민번호는 881120-1068234이다. 홍길동씨의 주민등록번호를 생년월일 (YYYYMMDD) 부분과 그 뒷의 숫자 부분으로 나우어 출력해보자

# %%
pin = "881120-1068234"
yyyymmdd=pin[0:6]
num=pin[7:17]
print("생년월일: %s" % yyyymmdd)
print("Num: %s" % num )
# Out:
# 생년월일: 881120
# Num: 1068234

# %% [markdown]
# - Quiz 2
# > 홍길동(881120-1068234)을 성명,주민번호로 구성되는  리스트로 만들고 성별을 체크하여 추가 하세요
# > 그리고 그 결과를 출력 하세요.
#
# pin = "881120-1068234"
# yyyymmdd=""
# num=""
# print("생년월일: %s" % yyyymmdd)
# print("Num: %s" % num )

# %%
pin = ["881120-2068234"]   # 리스트 선언 해서 다루는것 ? 
pin[0][7]

print(pin[0][7])  

if( pin[0][7] != '2'):   # !=의 의미는 :    조건연산자      
                         # 프로그램에서 다루는 데이터가 문자열인데 숫자료 비교 해서 
    pin.append('남')
else:
    pin.append('여')
    
#pin.append('')
print(pin)
#print( pin#pin.append('남')
type(pin[0][7])
# Out:
# 2
# ['881120-2068234', '여']
# str

# %%
pin = ["881120-1068234",[0,1,2312]]  #다중 리스트 복잡

pin[0][7]
#pin[0][7]
# Out:
# '1'

# %% [markdown]
# - Quiz 3
# > [1,2,3,4,5]라는 리스트를 [5,4,3,2,1]로 변경해 보세요.

# %%
a=[1,2,3,4,5]
a.sort(3)   # 정렬하기 
#print(a)
a.reverse()
print(a)

#실습 해보 하면 3시 13분까지 휴식 하겠습니다.
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-13-ba53c5f992b5> in <module>()
#       1 a=[1,2,3,4,5]
# ----> 2 a.sort(3)   # 정렬하기
#       3 #print(a)
#       4 a.reverse()
#       5 print(a)
#
# TypeError: must use keyword argument for key function

# %%
## python 으로 웹페이지를 자동으로 수집하는 로직을 구현하고 있어서 확인해보니 requests, bs4 라는 파이션 모듈이 있는것을 알게 되었다
## 해당 모듈을 설치 하여라.  

import requests  # 웹을 다루는 모둘
import bs4

# %%
import pandas as pd
import numpy as np

df = pd.DataFrame(np.random.randn(5, 3), columns=list('ABC'))
lst = np.arange(10)

df
lst
# Out:
# ---------------------------------------------------------------------------
# ImportError                               Traceback (most recent call last)
# <ipython-input-2-bd8b69b0fd57> in <module>()
# ----> 1 import pandas as pd
#       2 import numpy as np
#       3
#       4 df = pd.DataFrame(np.random.randn(5, 3), columns=list('ABC'))
#       5 lst = np.arange(10)
#
# c:\python36\lib\site-packages\pandas\__init__.py in <module>()
#      16
#      17 if missing_dependencies:
# ---> 18     raise ImportError("Missing required dependencies {0}".format(missing_dependencies))
#      19 del hard_dependencies, dependency, missing_dependencies
#      20
#
# ImportError: Missing required dependencies ['numpy']
