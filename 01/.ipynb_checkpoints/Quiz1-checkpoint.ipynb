# %% [markdown]
# - Quiz 1
# >홍길동 씨의 주민번호는 881120-1068234이다. 홍길동씨의 주민등록번호를 생년월일 (YYYYMMDD) 부분과 그 뒷의 숫자 부분으로 나우어 출력해보자

# %%
pin = "881120-1068234"
yyyymmdd=""
num=""
 ("생년월일: %" % yyyymmdd)
print("Num: %s" % num )
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-4-15ca43a24b64> in <module>()
#       2 yyyymmdd=""
#       3 num=""
# ----> 4 print("생년월일: %" % yyyymmdd)
#       5 print("Num: %s" % num )
#
# ValueError: incomplete format

# %% [markdown]
# - Quiz 2
# > 홍길동(881120-1068234)을 성명,주민번호로 구성되는  리스트로 만들고 성별을 체크하여 추가 하세요
# > 그리고 그 결과를 출력 하세요.
#
# pin = "881120-1068234"
# yyyymmdd=""
# num=""
# print("생년월일: %s" % yyyymmdd)
# print("Num: %s" % num )

# %%
pin = ["881120-1068234"]

print(pin[0][7])

if( pin[0][7]!=2):   # !=의 의미는 : 
    pin.append('남')
else:
    pin.append('여')
    

print(pin)
#print( pin#pin.append('남')
# Out:
# 1
# ['881120-1068234', '남']

# %% [markdown]
# - Quiz 3
# > [1,2,3,4,5]라는 리스트를 [5,4,3,2,1]로 변경해 보세요.

# %%
a=[1,2,3,4,5]
a.sort()   # 정렬하기 
#print(a)
a.reverse()
print(a)
# Out:
# [5, 4, 3, 2, 1]

# %%
## python 으로 웹페이지를 자동으로 수집하는 로직을 구현하고 있어서 확인해보니 requests, bs4 라는 파이션 모듈이 있는것을 알게 되었다
## 해당 모듈을 설치 하여라.  

import requests  
import bs4
