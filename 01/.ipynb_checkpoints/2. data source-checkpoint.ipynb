# %% [markdown]
# #수강 전 준비
# * 공공데이터포털(http://data.go.kr) 가입
# * library 설치
#     * pip install lxml html5lib xlrd requests pysimplesoap

# %% [markdown]
# #데이터 구경하기
# ## Open API
# * API (Application Programming Interface)
#     * 기능의 입력과 출력에 대한 약속
# * Web API
#     * 웹을 통해 이용할 수 있는 기능에 대한 API
# * 누구나 사용가능하도록 공개된 Web API
#   * 인증키가 필요한 경우가 있음
#   * 서비스의 경우 서드파티 어플리케이션 개발을 위해 SDK (Software Development Kit) 를 제공하기도 함
# * Open API 를 이용
#   * 데이터 수집
#   * 데이터와 메시업(Mesh up)
#   * 서비스 개발
#       * 다음지도 API + 부동산 매물 데이터 = 직방 지도 서비스
# * 예제
#   * http://openapi.airport.co.kr/service/rest/AirportCodeList/getAirportCodeList?serviceKey=<인증키>&schLineType=I&_type=json&pageNo=2
# * Open API 의 기능을 직접 만들거나 데이터셋을 구축할 필요가 없다.
#
#
# ##Crawling
#   * 온라인에 게시되어 있는 리소스를 수집
#   * 리소스의 구조나 스타일이 반복되는 내용을 파싱하여 데이터화 할 수 있음

# %% [markdown]
# #Open API 의 데이터 타입
# ## XML (eXtensible Markup Language)
# * <태그> 등으로 문서나 데이터 구조를 명시하는 마크업 언어
# ```
# <employees>
#     <employee>
#         <firstName>John</firstName> <lastName>Doe</lastName>
#     </employee>
#     <employee>
#         <firstName>Anna</firstName> <lastName>Smith</lastName>
#     </employee>
#     <employee>
#         <firstName>Peter</firstName> <lastName>Jones</lastName>
#     </employee>
# </employees>
# ```
#
# ## JSON (Javascript Object Notation)
# * Javascript 의 자료 표현 언어
# ```
# {"employees":[
#     {"firstName":"John", "lastName":"Doe"},
#     {"firstName":"Anna", "lastName":"Smith"},
#     {"firstName":"Peter", "lastName":"Jones"}
# ]}
# ```

# %% [markdown]
# #Open API 의 종류
# ## SOAP (Simple Object Access Protocol)
# * XML 기반의 메시지 통신
# * XML 로 Request 메시지를 구성해야 함
#
# ## REST (Representational safe transfer)
# * URL + Method 요청
# * Method
#     * **GET** - 우리가 사용할 Method
#     * POST
#     * DELETE / PUT

# %% [markdown]
# #공공데이터 가져오기
# ## 공공데이터
#     * 정부에서 생성하는 모든 데이터 중 공개된 데이터
#     * Open API, FIle, Link, Service 형태로 제공
#
# * 공공데이터포탈 : http://data.go.kr
#
# * 서울시 열린데이터광장 : http://data.seoul.go.kr

# %%
import requests
import json

# %%
servicekey = 'oVe6oF+10r9lo1LeluHJsTCvWRr19wnrvlp0NKaZmrVUTBwevUP04ENshg23yrmpUGxuQewqLnxWKW0Gr0CArw=='
endpoint = 'http://openapi.airport.co.kr/service'

rest = '/rest/AirportCodeList/getAirportCodeList'
params = { 'serviceKey' : servicekey, 'schLineType' : 'I', '_type' : 'json', 'pageNo' : 2 }

# %%
response = requests.get(endpoint+rest, params = params)
response
# Out:
# <Response [200]>

# %% [markdown]
# endpoint+rest?
# * 파이썬에서는 '+' 연산자로 문자열을 연결할 수 있다.
# * http://openapi.airport.co.kr/service/rest/AirportCodeList/getAirportCodeList
#
# params
# * URL 뒤에 API 에서 정의한 정보를 전달하기 위해 사용
# * getAirportCodeList?_type=json&schLineType=I&serviceKey=<인증키>&pageNo=2'
#
# response (http://ko.wikipedia.org/wiki/HTTP_%EC%83%81%ED%83%9C_%EC%BD%94%EB%93%9C)
# * 200 - OK
# * 404 - Not Found
# * 500 - Server Error

# %%
response.text
# Out:
# u'{"response":{"header":{"resultCode":"00","resultMsg":"NORMAL SERVICE."},"body":{"items":{"item":[{"cityCode":"KUV","cityEng":"GUNSAN","cityJpn":"\u30af\u30f3\u30b5\u30f3","cityKor":"\uad70\uc0b0"},{"cityCode":"KWJ","cityEng":"GWANGJU","cityJpn":"\u30af\u30a2\u30f3\u30b8\u30e5","cityKor":"\uad11\uc8fc"},{"cityChn":"\uf91f\u5dde","cityCode":"LHW","cityEng":"LANZHOU","cityJpn":"\uf91f\u5dde","cityKor":"\ub780\uc800\uc6b0"},{"cityChn":"\u6fb3\u9580","cityCode":"MFM","cityEng":"MACAU","cityJpn":"\u6fb3\u9580","cityKor":"\ub9c8\uce74\uc624"},{"cityCode":"MKO","cityEng":"MAKAU","cityKor":"\ub9c8\uce74\uc624"},{"cityCode":"MMB","cityEng":"MEMANBETSU","cityJpn":"\u30df\u30de\u30f3\u30c6\u30b9","cityKor":"\uba54\ub9cc\ubca0\uce20"},{"cityCode":"MNL","cityEng":"MANILA","cityJpn":"\u30de\u30cb\u30e9","cityKor":"\ub9c8\ub2d0\ub77c"},{"cityCode":"MPK","cityEng":"MOKPO","cityKor":"\ubaa9\ud3ec"},{"cityCode":"MRO","cityEng":"MORIOKA","cityKor":"\ubaa8\ub9ac\uc624\uce74"},{"cityCode":"MWX","cityEng":"MUAN","cityKor":"\ubb34\uc548"}]},"numOfRows":10,"pageNo":2,"totalCount":155}}}'

# %%
result = response.json()

# %%
result
# Out:
# {u'response': {u'body': {u'items': {u'item': [{u'cityCode': u'KUV',
#       u'cityEng': u'GUNSAN',
#       u'cityJpn': u'\u30af\u30f3\u30b5\u30f3',
#       u'cityKor': u'\uad70\uc0b0'},
#      {u'cityCode': u'KWJ',
#       u'cityEng': u'GWANGJU',
#       u'cityJpn': u'\u30af\u30a2\u30f3\u30b8\u30e5',
#       u'cityKor': u'\uad11\uc8fc'},
#      {u'cityChn': u'\uf91f\u5dde',
#       u'cityCode': u'LHW',
#       u'cityEng': u'LANZHOU',
#       u'cityJpn': u'\uf91f\u5dde',
#       u'cityKor': u'\ub780\uc800\uc6b0'},
#      {u'cityChn': u'\u6fb3\u9580',
#       u'cityCode': u'MFM',
#       u'cityEng': u'MACAU',
#       u'cityJpn': u'\u6fb3\u9580',
#       u'cityKor': u'\ub9c8\uce74\uc624'},
#      {u'cityCode': u'MKO',
#       u'cityEng': u'MAKAU',
#       u'cityKor': u'\ub9c8\uce74\uc624'},
#      {u'cityCode': u'MMB',
#       u'cityEng': u'MEMANBETSU',
#       u'cityJpn': u'\u30df\u30de\u30f3\u30c6\u30b9',
#       u'cityKor': u'\uba54\ub9cc\ubca0\uce20'},
#      {u'cityCode': u'MNL',
#       u'cityEng': u'MANILA',
#       u'cityJpn': u'\u30de\u30cb\u30e9',
#       u'cityKor': u'\ub9c8\ub2d0\ub77c'},
#      {u'cityCode': u'MPK', u'cityEng': u'MOKPO', u'cityKor': u'\ubaa9\ud3ec'},
#      {u'cityCode': u'MRO',
#       u'cityEng': u'MORIOKA',
#       u'cityKor': u'\ubaa8\ub9ac\uc624\uce74'},
#      {u'cityCode': u'MWX', u'cityEng': u'MUAN', u'cityKor': u'\ubb34\uc548'}]},
#    u'numOfRows': 10,
#    u'pageNo': 2,
#    u'totalCount': 155},
#   u'header': {u'resultCode': u'00', u'resultMsg': u'NORMAL SERVICE.'}}}

# %% [markdown]
# ‘response' -> 'body' -> 'items' -> 'item'

# %%
result['response']['body']['items']['item']
# Out:
# [{u'cityCode': u'KUV',
#   u'cityEng': u'GUNSAN',
#   u'cityJpn': u'\u30af\u30f3\u30b5\u30f3',
#   u'cityKor': u'\uad70\uc0b0'},
#  {u'cityCode': u'KWJ',
#   u'cityEng': u'GWANGJU',
#   u'cityJpn': u'\u30af\u30a2\u30f3\u30b8\u30e5',
#   u'cityKor': u'\uad11\uc8fc'},
#  {u'cityChn': u'\uf91f\u5dde',
#   u'cityCode': u'LHW',
#   u'cityEng': u'LANZHOU',
#   u'cityJpn': u'\uf91f\u5dde',
#   u'cityKor': u'\ub780\uc800\uc6b0'},
#  {u'cityChn': u'\u6fb3\u9580',
#   u'cityCode': u'MFM',
#   u'cityEng': u'MACAU',
#   u'cityJpn': u'\u6fb3\u9580',
#   u'cityKor': u'\ub9c8\uce74\uc624'},
#  {u'cityCode': u'MKO',
#   u'cityEng': u'MAKAU',
#   u'cityKor': u'\ub9c8\uce74\uc624'},
#  {u'cityCode': u'MMB',
#   u'cityEng': u'MEMANBETSU',
#   u'cityJpn': u'\u30df\u30de\u30f3\u30c6\u30b9',
#   u'cityKor': u'\uba54\ub9cc\ubca0\uce20'},
#  {u'cityCode': u'MNL',
#   u'cityEng': u'MANILA',
#   u'cityJpn': u'\u30de\u30cb\u30e9',
#   u'cityKor': u'\ub9c8\ub2d0\ub77c'},
#  {u'cityCode': u'MPK', u'cityEng': u'MOKPO', u'cityKor': u'\ubaa9\ud3ec'},
#  {u'cityCode': u'MRO',
#   u'cityEng': u'MORIOKA',
#   u'cityKor': u'\ubaa8\ub9ac\uc624\uce74'},
#  {u'cityCode': u'MWX', u'cityEng': u'MUAN', u'cityKor': u'\ubb34\uc548'}]

# %%
import pandas as pd
res = json.loads(response.content, encoding='utf-8')
df = pd.DataFrame(res['response']['body']['items']['item'])
print df
# Out:
#   cityChn cityCode     cityEng cityJpn cityKor
# 0     NaN      KUV      GUNSAN    クンサン      군산
# 1     NaN      KWJ     GWANGJU   クアンジュ      광주
# 2      蘭州      LHW     LANZHOU      蘭州     란저우
# 3      澳門      MFM       MACAU      澳門     마카오
# 4     NaN      MKO       MAKAU     NaN     마카오
# 5     NaN      MMB  MEMANBETSU   ミマンテス    메만베츠
# 6     NaN      MNL      MANILA     マニラ     마닐라
# 7     NaN      MPK       MOKPO     NaN      목포
# 8     NaN      MRO     MORIOKA     NaN    모리오카
# 9     NaN      MWX        MUAN     NaN      무안

# %%
import sys
# reload(sys)
sys.getdefaultencoding()

# %%
sys.stdout

# %%
print '[[국제선 공항 코드 목록]]'
for item in result['response']['body']['items']['item']:
    item = item.items() #dictionary 자료형을 출력하기 쉽도록 tuple 로 재구성
    print item
    for k,v in item:
        print k,v, v
    print '--------------'
# Out:
# [[국제선 공항 코드 목록]]
# [(u'cityEng', u'GUNSAN'), (u'cityKor', u'\uad70\uc0b0'), (u'cityCode', u'KUV'), (u'cityJpn', u'\u30af\u30f3\u30b5\u30f3')]
# cityEng GUNSAN GUNSAN
# cityKor 군산 군산
# cityCode KUV KUV
# cityJpn クンサン クンサン
# --------------
# [(u'cityEng', u'GWANGJU'), (u'cityKor', u'\uad11\uc8fc'), (u'cityCode', u'KWJ'), (u'cityJpn', u'\u30af\u30a2\u30f3\u30b8\u30e5')]
# cityEng GWANGJU GWANGJU
# cityKor 광주 광주
# cityCode KWJ KWJ
# cityJpn クアンジュ クアンジュ
# --------------
# [(u'cityEng', u'LANZHOU'), (u'cityKor', u'\ub780\uc800\uc6b0'), (u'cityCode', u'LHW'), (u'cityJpn', u'\uf91f\u5dde'), (u'cityChn', u'\uf91f\u5dde')]
# cityEng LANZHOU LANZHOU
# cityKor 란저우 란저우
# cityCode LHW LHW
# cityJpn 蘭州 蘭州
# cityChn 蘭州 蘭州
# --------------
# [(u'cityEng', u'MACAU'), (u'cityKor', u'\ub9c8\uce74\uc624'), (u'cityCode', u'MFM'), (u'cityJpn', u'\u6fb3\u9580'), (u'cityChn', u'\u6fb3\u9580')]
# cityEng MACAU MACAU
# cityKor 마카오 마카오
# cityCode MFM MFM
# cityJpn 澳門 澳門
# cityChn 澳門 澳門
# --------------
# [(u'cityEng', u'MAKAU'), (u'cityCode', u'MKO'), (u'cityKor', u'\ub9c8\uce74\uc624')]
# cityEng MAKAU MAKAU
# cityCode MKO MKO
# cityKor 마카오 마카오
# --------------
# [(u'cityEng', u'MEMANBETSU'), (u'cityKor', u'\uba54\ub9cc\ubca0\uce20'), (u'cityCode', u'MMB'), (u'cityJpn', u'\u30df\u30de\u30f3\u30c6\u30b9')]
# cityEng MEMANBETSU MEMANBETSU
# cityKor 메만베츠 메만베츠
# cityCode MMB MMB
# cityJpn ミマンテス ミマンテス
# --------------
# [(u'cityEng', u'MANILA'), (u'cityKor', u'\ub9c8\ub2d0\ub77c'), (u'cityCode', u'MNL'), (u'cityJpn', u'\u30de\u30cb\u30e9')]
# cityEng MANILA MANILA
# cityKor 마닐라 마닐라
# cityCode MNL MNL
# cityJpn マニラ マニラ
# --------------
# [(u'cityEng', u'MOKPO'), (u'cityCode', u'MPK'), (u'cityKor', u'\ubaa9\ud3ec')]
# cityEng MOKPO MOKPO
# cityCode MPK MPK
# cityKor 목포 목포
# --------------
# [(u'cityEng', u'MORIOKA'), (u'cityCode', u'MRO'), (u'cityKor', u'\ubaa8\ub9ac\uc624\uce74')]
# cityEng MORIOKA MORIOKA
# cityCode MRO MRO
# cityKor 모리오카 모리오카
# --------------
# [(u'cityEng', u'MUAN'), (u'cityCode', u'MWX'), (u'cityKor', u'\ubb34\uc548')]
# cityEng MUAN MUAN
# cityCode MWX MWX
# cityKor 무안 무안
# --------------

# %% [markdown]
# print k,v
# * 문자열에 대해 띄어쓰기로 출력

# %%
rest2 = '/rest/FlightScheduleList/getIflightScheduleList'

# %%
data = requests.get(endpoint+rest2, params = params)
result = data.json()
print result
# Out:
# {u'response': {u'body': {u'items': {u'item': [{u'internationalSat': u'Y', u'city': u'\ud64d\ucf69', u'airlineKorean': u'\uc5d0\uc5b4\ubd80\uc0b0', u'internationalStdate': u'2016-10-30T00:00:00+09:00', u'internationalMon': u'Y', u'internationalFri': u'Y', u'internationalTime': u'0610', u'internationalWed': u'Y', u'airport': u'\uae40\ud574', u'airlineHomepageUrl': u'www.flyairbusan.com', u'internationalNum': u'BX392', u'internationalThu': u'Y', u'internationalSun': u'Y', u'internationalEddate': u'2017-03-25T00:00:00+09:00', u'internationalIoType': u'IN', u'internationalTue': u'Y'}, {u'internationalSat': u'Y', u'city': u'\ub09c\ub2dd', u'airlineKorean': u'\ud2f0\uc6e8\uc774\ud56d\uacf5', u'internationalStdate': u'2016-10-31T00:00:00+09:00', u'internationalMon': u'N', u'internationalFri': u'N', u'internationalTime': u'0610', u'internationalWed': u'N', u'airport': u'\uc81c\uc8fc', u'airlineHomepageUrl': u'www.twayair.com', u'internationalNum': u'TW632', u'internationalThu': u'Y', u'internationalSun': u'N', u'internationalEddate': u'2017-03-26T00:00:00+09:00', u'internationalIoType': u'IN', u'internationalTue': u'Y'}, {u'internationalSat': u'Y', u'city': u'\ucf54\ud0c0\ud0a4\ub098\ubc1c\ub8e8', u'airlineKorean': u'\uc774\uc2a4\ud0c0\ud56d\uacf5', u'internationalStdate': u'2016-10-30T00:00:00+09:00', u'internationalMon': u'Y', u'internationalFri': u'Y', u'internationalTime': u'0610', u'internationalWed': u'Y', u'airport': u'\uae40\ud574', u'airlineHomepageUrl': u'www.eastarjet.com', u'internationalNum': u'ZE942', u'internationalThu': u'Y', u'internationalSun': u'Y', u'internationalEddate': u'2017-03-25T00:00:00+09:00', u'internationalIoType': u'IN', u'internationalTue': u'Y'}, {u'internationalSat': u'N', u'city': u'\uc0ac\uc774\ud310', u'airlineKorean': u'\uc81c\uc8fc\ud56d\uacf5', u'internationalStdate': u'2016-10-30T00:00:00+09:00', u'internationalMon': u'Y', u'internationalFri': u'Y', u'internationalTime': u'0610', u'internationalWed': u'N', u'airport': u'\uae40\ud574', u'airlineHomepageUrl': u'www.jejuair.net', u'internationalNum': u'7C3451', u'internationalThu': u'Y', u'internationalSun': u'Y', u'internationalEddate': u'2017-03-25T00:00:00+09:00', u'internationalIoType': u'IN', u'internationalTue': u'N'}, {u'internationalSat': u'Y', u'city': u'\ud0c0\uc774\ud398\uc774(\ud0c0\uc624\uc704\uc548)', u'airlineKorean': u'\uc81c\uc8fc\ud56d\uacf5', u'internationalStdate': u'2016-10-30T00:00:00+09:00', u'internationalMon': u'Y', u'internationalFri': u'Y', u'internationalTime': u'0610', u'internationalWed': u'Y', u'airport': u'\uae40\ud574', u'airlineHomepageUrl': u'www.jejuair.net', u'internationalNum': u'7C2654', u'internationalThu': u'Y', u'internationalSun': u'Y', u'internationalEddate': u'2017-03-25T00:00:00+09:00', u'internationalIoType': u'IN', u'internationalTue': u'Y'}, {u'internationalSat': u'Y', u'city': u'\ub9c8\uce74\uc624', u'airlineKorean': u'\uc5d0\uc5b4\ubd80\uc0b0', u'internationalStdate': u'2016-10-30T00:00:00+09:00', u'internationalMon': u'Y', u'internationalFri': u'N', u'internationalTime': u'0615', u'internationalWed': u'N', u'airport': u'\uae40\ud574', u'airlineHomepageUrl': u'www.flyairbusan.com', u'internationalNum': u'BX382', u'internationalThu': u'Y', u'internationalSun': u'N', u'internationalEddate': u'2017-03-25T00:00:00+09:00', u'internationalIoType': u'IN', u'internationalTue': u'N'}, {u'internationalSat': u'N', u'city': u'\uc2dc\uc548', u'airlineKorean': u'\uc5d0\uc5b4\ubd80\uc0b0', u'internationalStdate': u'2016-10-30T00:00:00+09:00', u'internationalMon': u'N', u'internationalFri': u'Y', u'internationalTime': u'0615', u'internationalWed': u'N', u'airport': u'\uae40\ud574', u'airlineHomepageUrl': u'www.flyairbusan.com', u'internationalNum': u'BX342', u'internationalThu': u'Y', u'internationalSun': u'Y', u'internationalEddate': u'2017-03-25T00:00:00+09:00', u'internationalIoType': u'IN', u'internationalTue': u'Y'}, {u'internationalSat': u'Y', u'city': u'\ud64d\ucf69', u'airlineKorean': u'\ub300\ud55c\ud56d\ ...

# %%
for item in result['response']['body']['items']['item']:
    item = item.items()
    for k,v in item:
        print k,v
    print '--------------'
# Out:
# internationalSat Y
# city 홍콩
# airlineKorean 에어부산
# internationalStdate 2016-10-30T00:00:00+09:00
# internationalMon Y
# internationalFri Y
# internationalTime 0610
# internationalWed Y
# airport 김해
# airlineHomepageUrl www.flyairbusan.com
# internationalNum BX392
# internationalThu Y
# internationalSun Y
# internationalEddate 2017-03-25T00:00:00+09:00
# internationalIoType IN
# internationalTue Y
# --------------
# internationalSat Y
# city 난닝
# airlineKorean 티웨이항공
# internationalStdate 2016-10-31T00:00:00+09:00
# internationalMon N
# internationalFri N
# internationalTime 0610
# internationalWed N
# airport 제주
# airlineHomepageUrl www.twayair.com
# internationalNum TW632
# internationalThu Y
# internationalSun N
# internationalEddate 2017-03-26T00:00:00+09:00
# internationalIoType IN
# internationalTue Y
# --------------
# internationalSat Y
# city 코타키나발루
# airlineKorean 이스타항공
# internationalStdate 2016-10-30T00:00:00+09:00
# internationalMon Y
# internationalFri Y
# internationalTime 0610
# internationalWed Y
# airport 김해
# airlineHomepageUrl www.eastarjet.com
# internationalNum ZE942
# internationalThu Y
# internationalSun Y
# internationalEddate 2017-03-25T00:00:00+09:00
# internationalIoType IN
# internationalTue Y
# --------------
# internationalSat N
# city 사이판
# airlineKorean 제주항공
# internationalStdate 2016-10-30T00:00:00+09:00
# internationalMon Y
# internationalFri Y
# internationalTime 0610
# internationalWed N
# airport 김해
# airlineHomepageUrl www.jejuair.net
# internationalNum 7C3451
# internationalThu Y
# internationalSun Y
# internationalEddate 2017-03-25T00:00:00+09:00
# internationalIoType IN
# internationalTue N
# --------------
# internationalSat Y
# city 타이페이(타오위안)
# airlineKorean 제주항공
# internationalStdate 2016-10-30T00:00:00+09:00
# internationalMon Y
# internationalFri Y
# internationalTime 0610
# internationalWed Y
# airport 김해
# airlineHomepageUrl www.jejuair.net
# internationalNum 7C2654
# internationalThu Y
# internationalSun Y
# internationalEddate 2017-03-25T00:00:00+09:00
# internationalIoType IN
# internationalTue Y
# --------------
# internationalSat Y
# city 마카오
# airlineKorean 에어부산
# internationalStdate 2016-10-30T00:00:00+09:00
# internationalMon Y
# internationalFri N
# internationalTime 0615
# internationalWed N
# airport 김해
# airlineHomepageUrl www.flyairbusan.com
# internationalNum BX382
# internationalThu Y
# internationalSun N
# internationalEddate 2017-03-25T00:00:00+09:00
# internationalIoType IN
# internationalTue N
# --------------
# internationalSat N
# city 시안
# airlineKorean 에어부산
# internationalStdate 2016-10-30T00:00:00+09:00
# internationalMon N
# internationalFri Y
# internationalTime 0615
# internationalWed N
# airport 김해
# airlineHomepageUrl www.flyairbusan.com
# internationalNum BX342
# internationalThu Y
# internationalSun Y
# internationalEddate 2017-03-25T00:00:00+09:00
# internationalIoType IN
# internationalTue Y
# --------------
# internationalSat Y
# city 홍콩
# airlineKorean 대한항공
# internationalStdate 2016-10-30T00:00:00+09:00
# internationalMon Y
# internationalFri Y
# internationalTime 0620
# internationalWed Y
# airport 김해
# airlineHomepageUrl www.koreanair.co.kr
# internationalNum KE618
# internationalThu Y
# internationalSun Y
# internationalEddate 2017-03-25T00:00:00+09:00
# internationalIoType IN
# internationalTue Y
# --------------
# internationalSat N
# city 사이판
# airlineKorean 아시아나항공
# internationalStdate 2016-10-30T00:00:00+09:00
# internationalMon N
# internationalFri N
# internationalTime 0620
# internationalWed N
# airport 김해
# airlineHomepageUrl www.flyasiana.com
# internationalNum OZ608
# internationalThu Y
# internationalSun Y
# internationalEddate 2017-03-25T00:00:00+09:00
# internationalIoType IN
# internationalTue N
# --------------
# internationalSat N
# city 광쪄우
# airlineKorean 아시아나항공
# internationalStdate 2016-10-30T00:00:00+09:00
# internationalMon Y
# internationalFri Y
# internationalTime 0620
# internationalWed N
# airport 김해
# airlineHomepageUrl www.flyasiana.com
# internationalNum OZ306
# internationalThu N
# internationalSun N
# internationalEddate 2017-03-25T00:00:00+09:00
# internationalIoType IN
# internationalTue N
# --------------

# %%
import pandas as pd
df2 = pd.DataFrame(result['response']['body']['items']['item'])
df2
# Out:
#     airlineHomepageUrl airlineKorean airport        city  \
# 0  www.flyairbusan.com          에어부산      김해          홍콩
# 1      www.twayair.com         티웨이항공      제주          난닝
# 2    www.eastarjet.com         이스타항공      김해      코타키나발루
# 3      www.jejuair.net          제주항공      김해         사이판
# 4      www.jejuair.net          제주항공      김해  타이페이(타오위안)
# 5  www.flyairbusan.com          에어부산      김해         마카오
# 6  www.flyairbusan.com          에어부산      김해          시안
# 7  www.koreanair.co.kr          대한항공      김해          홍콩
# 8    www.flyasiana.com        아시아나항공      김해         사이판
# 9    www.flyasiana.com        아시아나항공      김해         광쪄우
#
#          internationalEddate internationalFri internationalIoType  \
# 0  2017-03-25T00:00:00+09:00                Y                  IN
# 1  2017-03-26T00:00:00+09:00                N                  IN
# 2  2017-03-25T00:00:00+09:00                Y                  IN
# 3  2017-03-25T00:00:00+09:00                Y                  IN
# 4  2017-03-25T00:00:00+09:00                Y                  IN
# 5  2017-03-25T00:00:00+09:00                N                  IN
# 6  2017-03-25T00:00:00+09:00                Y                  IN
# 7  2017-03-25T00:00:00+09:00                Y                  IN
# 8  2017-03-25T00:00:00+09:00                N                  IN
# 9  2017-03-25T00:00:00+09:00                Y                  IN
#
#   internationalMon internationalNum internationalSat  \
# 0                Y            BX392                Y
# 1                N            TW632                Y
# 2                Y            ZE942                Y
# 3                Y           7C3451                N
# 4                Y           7C2654                Y
# 5                Y            BX382                Y
# 6                N            BX342                N
# 7                Y            KE618                Y
# 8                N            OZ608                N
# 9                Y            OZ306                N
#
#          internationalStdate internationalSun internationalThu  \
# 0  2016-10-30T00:00:00+09:00                Y                Y
# 1  2016-10-31T00:00:00+09:00                N                Y
# 2  2016-10-30T00:00:00+09:00                Y                Y
# 3  2016-10-30T00:00:00+09:00                Y                Y
# 4  2016-10-30T00:00:00+09:00                Y                Y
# 5  2016-10-30T00:00:00+09:00                N                Y
# 6  2016-10-30T00:00:00+09:00                Y                Y
# 7  2016-10-30T00:00:00+09:00                Y                Y
# 8  2016-10-30T00:00:00+09:00                Y                Y
# 9  2016-10-30T00:00:00+09:00                N                N
#
#   internationalTime internationalTue internationalWed
# 0              0610                Y                Y
# 1              0610                Y                N
# 2              0610                Y                Y
# 3              0610                N                N
# 4              0610                Y                Y
# 5              0615                N                N
# 6              0615                Y                N
# 7              0620                Y                Y
# 8              0620                N                N
# 9              0620                N                N

# %% [markdown]
# ###XML 데이터

# %%
import requests
import json
import xml.etree.ElementTree as et
import pandas as pd

res_subway = requests.get('http://openapi.seoul.go.kr:8088/7163686f486c75693436464f707148/xml/CardSubwayTime/1/5/201503/3호선/신사/')
# print res_subway.content
# print res_subway.text
xml_subway = et.fromstring(res_subway.content)

if xml_subway.find('row') is not None:    
    rows = xml_subway.iter('row')
    df_subway = pd.DataFrame(columns=['name', 'value'])
    # count = 0
    for row in rows.next():
#         print zip(['name', 'value'],[row.tag, row.text])
        r = dict(zip(['name', 'value'],[row.tag, row.text]))
        r_s = pd.Series(r)
    #     r_s.name = count
        df_subway = df_subway.append(r_s, ignore_index=True)
    #     count += 1


    df_subway = df_subway.replace({'RIDE_NUM' : '승차인원'}, regex=True)
    df_subway = df_subway.replace({'ALIGHT_NUM' : '하차인원'}, regex=True)

    timewords = [ "MIDNIGHT", "ONE", "TWO", "THREE", "FOUR", "FIVE", "SIX", "SEVEN", "EIGHT", "NINE", "TEN", 
             "ELEVEN", "TWELVE", "THIRTEEN", "FOURTEEN", "FIFTEEN", "SIXTEEN", "SEVENTEEN", "EIGHTEEN", "NINETEEN",
             "TWENTY", "TWENTY_ONE", "TWENTY_TWO", "TWENTY_THREE"
            ]
    timewords.reverse()

    numwords = []
    for idx, word in enumerate(timewords):    
        numwords.append(str(idx) + '시')

    numwords.reverse()

    df_subway = df_subway.replace(timewords, numwords, regex=True)

df_subway
# Out:
#           name     value
# 0      USE_MON    201503
# 1     LINE_NUM       3호선
# 2   SUB_STA_NM        신사
# 3      4시_승차인원        62
# 4      4시_하차인원         4
# 5      5시_승차인원      5120
# 6      5시_하차인원      1414
# 7      6시_승차인원      8747
# 8      6시_하차인원     19326
# 9      7시_승차인원     18975
# 10     7시_하차인원     46499
# 11     8시_승차인원     26476
# 12     8시_하차인원    133889
# 13     9시_승차인원     22764
# 14     9시_하차인원    130411
# 15    10시_승차인원     21708
# 16    10시_하차인원     72712
# 17    11시_승차인원     28290
# 18    11시_하차인원     60340
# 19    12시_승차인원     34144
# 20    12시_하차인원     61083
# 21    13시_승차인원     43971
# 22    13시_하차인원     69057
# 23    14시_승차인원     51989
# 24    14시_하차인원     67278
# 25    15시_승차인원     61705
# 26    15시_하차인원     64103
# 27    16시_승차인원     68817
# 28    16시_하차인원     63873
# 29    17시_승차인원     85439
# 30    17시_하차인원     68592
# 31    18시_승차인원    139321
# 32    18시_하차인원     91485
# 33    19시_승차인원    120175
# 34    19시_하차인원     78655
# 35    20시_승차인원     82831
# 36    20시_하차인원     35389
# 37    21시_승차인원     91024
# 38    21시_하차인원     23717
# 39    22시_승차인원     85635
# 40    22시_하차인원     19807
# 41    23시_승차인원     38813
# 42    23시_하차인원     12390
# 43     0시_승차인원      4113
# 44     0시_하차인원      3928
# 45     1시_승차인원         1
# 46     1시_하차인원         3
# 47     2시_승차인원         1
# 48     2시_하차인원         0
# 49     3시_승차인원         0
# 50     3시_하차인원         0
# 51     WORK_DT  20151223

# %% [markdown]
# #SOAP Example

# %%
from pysimplesoap.client import SoapClient
client = SoapClient(wsdl='http://www.webservicex.com/currencyconvertor.asmx?WSDL')
# Out:
# No handlers could be found for logger "pysimplesoap.helpers"

# %%
client.services
# Out:
# {u'CurrencyConvertor': {u'documentation': u'',
#   u'ports': {u'CurrencyConvertorHttpGet': {u'location': None,
#     u'name': u'CurrencyConvertorHttpGet',
ands Dollar<br>SOS-Somali Shilling<br>ZAR-South African Rand<br>LKR-Sri Lanka Rupee<br>SHP-St Helena Pound<br>SDD-Sudanese Dinar<br>SRG-Surinam Guilder<br>SZL-Swaziland Lilageni<br>SEK-Swedish Krona<br>TRY-Turkey Lira<br>CHF-Swiss Franc<br>SYP-Syrian Pound<br>TWD-Taiwan Dollar<br>TZS-Tanzanian Shilling<br>THB-Thai Baht<br>TOP-Tonga Pa'anga<br>TTD-Trinidad&amp;amp;Tobago Dollar<br>TND-Tunisian Dinar<br>TRL-Turkish Lira<br>USD-U.S. Dollar<br>AED-UAE Dirham<br>UGX-Ugandan Shilling<br>UAH-Ukraine Hryvnia<br>UYU-Uruguayan New Peso<br>VUV-Vanuatu Vatu<br>VEB-Venezuelan Bolivar<br>VND-Vietnam Dong<br>YER-Yemen Riyal<br>YUM-Yugoslav Dinar<br>ZMK-Zambian Kwacha<br>ZWD-Zimbabwe Dollar</font></p></blockquote>",
#       u'fault_msgs': {},
#       u'faults': {},
#       u'header': {},
#       u'input': None,
#       u'name': u'ConversionRate',
#       u'namespace': u'http://www.webserviceX.NET/',
#       u'output': {'double': <alias 'double' for '<type 'float'>'>},
#       u'parameter_order': [u''],
#       u'qualified': None,
#       u'style': None}},
#     u'port_type_name': 'CurrencyConvertorHttpPost',
#     u'service_name': u'CurrencyConvertor',
#     u'soap_uri': None,
#     u'soap_ver': None,
#     u'style': None,
#     u'transport': None},
#    u'CurrencyConvertorSoap': {u'location': u'http://www.webservicex.com/currencyconvertor.asmx',
#     u'name': u'CurrencyConvertorSoap',
#     u'operations': {u'ConversionRate': {u'action': u'http://www.webserviceX.NET/ConversionRate',
#       u'documentation': u"<br><b>Get conversion rate from one currency to another currency <b><br><p><b><font color='#000080' size='1' face='Verdana'><u>Differenct currency Code and Names around the world</u></font></b></p><blockquote><p><font face='Verdana' size='1'>AFA-Afghanistan Afghani<br>ALL-Albanian Lek<br>DZD-Algerian Dinar<br>ARS-Argentine Peso<br>AWG-Aruba Florin<br>AUD-Australian Dollar<br>BSD-Bahamian Dollar<br>BHD-Bahraini Dinar<br>BDT-Bangladesh Taka<br>BBD-Barbados Dollar<br>BZD-Belize Dollar<br>BMD-Bermuda Dollar<br>BTN-Bhutan Ngultrum<br>BOB-Bolivian Boliviano<br>BWP-Botswana Pula<br>BRL-Brazilian Real<br>GBP-British Pound<br>BND-Brunei Dollar<br>BIF-Burundi Franc<br>XOF-CFA Franc (BCEAO)<br>XAF-CFA Franc (BEAC)<br>KHR-Cambodia Riel<br>CAD-Canadian Dollar<br>CVE-Cape Verde Escudo<br>KYD-Cayman Islands Dollar<br>CLP-Chilean Peso<br>CNY-Chinese Yuan<br>COP-Colombian Peso<br>KMF-Comoros Franc<br>CRC-Costa Rica Colon<br>HRK-Croatian Kuna<br>CUP-Cuban Peso<br>CYP-Cyprus Pound<br>CZK-Czech Koruna<br>DKK-Danish Krone<br>DJF-Dijibouti Franc<br>DOP-Dominican Peso<br>XCD-East Caribbean Doll
Dollar<br>TND-Tunisian Dinar<br>TRL-Turkish Lira<br>USD-U.S. Dollar<br>AED-UAE Dirham<br>UGX-Ugandan Shilling<br>UAH-Ukraine Hryvnia<br>UYU-Uruguayan New Peso<br>VUV-Vanuatu Vatu<br>VEB-Venezuelan Bolivar<br>VND-Vietnam Dong<br>YER-Yemen Riyal<br>YUM-Yugoslav Dinar<br>ZMK-Zambian Kwacha<br>ZWD-Zimbabwe Dollar</font></p></blockquote>",
#       u'fault_msgs': {},
#       u'faults': {},
#       u'header': {},
#       u'input': {'ConversionRate': {u'FromCurrency': <type 'str'>, u'ToCurrency': <type 'str'>}},
#       u'name': u'ConversionRate',
#       u'namespace': u'http://www.webserviceX.NET/',
#       u'output': {'ConversionRateResponse': {u'ConversionRateResult': <alias 'double' for '<type 'float'>'>}},
#       u'parameter_order': [u''],
#       u'qualified': True,
#       u'style': None}},
#     u'port_type_name': 'CurrencyConvertorSoap',
#     u'service_name': u'CurrencyConvertor',
#     u'soap_uri': u'http://schemas.xmlsoap.org/wsdl/soap/',
#     u'soap_ver': u'soap11',
#     u'style': None,
#     u'transport': u'http://schemas.xmlsoap.org/soap/http'},
#    u'CurrencyConvertorSoap12': {u'location': u'http://www.webservicex.com/currencyconvertor.asmx',
#     u'name': u'CurrencyConvertorSoap12',
#     u'operations': {u'ConversionRate': {u'action': u'http://www.webserviceX.NET/ConversionRate',
#       u'documentation': u"<br><b>Get conversion rate from one currency to another currency <b><br><p><b><font color='#000080' size='1' face='Verdana'><u>Differenct currency Code and Names around the world</u></font></b></p><blockquote><p><font face='Verdana' size='1'>AFA-Afghanistan Afghani<br>ALL-Albanian Lek<br>DZD-Algerian Dinar<br>ARS-Argentine Peso<br>AWG-Aruba Florin<br>AUD-Australian Dollar<br>BSD-Bahamian Dollar<br>BHD-Bahraini Dinar<br>BDT-Bangladesh Taka<br>BBD-Barbados Dollar<br>BZD-Belize Dollar<br>BMD-Bermuda Dollar<br>BTN-Bhutan Ngultrum<br>BOB-Bolivian Boliviano<br>BWP-Botswana Pula<br>BRL-Brazilian Real<br>GBP-British Pound<br>BND-Brunei Dollar<br>BIF-Burundi Franc<br>XOF-CFA Franc (BCEAO)<br>XAF-CFA Franc (BEAC)<br>KHR-Cambodia Riel<br>CAD-Canadian Dollar<br>CVE-Cape Verde Escudo<br>KYD-Cayman Islands Dollar<br>CLP-Chilean Peso<br>CNY-Chinese Yuan<br>COP-Colombian Peso<br>KMF-Comoros Franc<br>CRC-Costa Rica Colon<br>HRK-Croatian Kuna<br>CUP-Cuban Peso<br>CYP-Cyprus Pound<br>CZK-Czech Koruna<br>DKK-Danish Krone<br>DJF-Dijibouti Franc<br>DOP-Dominican Peso<br>XCD-East Caribbean Dollar<br>EGP-Egyptian Pound<br>SVC-El Salvador Colon<br>EEK-Estonian Kroon<br>ETB-Ethiopian Birr<br>EUR-Euro<br>FKP-Falkland Islands Pound<br>GMD-Gambian Dalasi<br>GHC-Ghanian Cedi<br>GIP-Gibraltar Pound<br>
#       u'fault_msgs': {},
#       u'faults': {},
#       u'header': {},
#       u'input': {'ConversionRate': {u'FromCurrency': <type 'str'>, u'ToCurrency': <type 'str'>}},
#       u'name': u'ConversionRate',
#       u'namespace': u'http://www.webserviceX.NET/',
#       u'output': {'ConversionRateResponse': {u'ConversionRateResult': <alias 'double' for '<type 'float'>'>}},
#       u'parameter_order': [u''],
#       u'qualified': True,
#       u'style': None}},
#     u'port_type_name': 'CurrencyConvertorSoap',
#     u'service_name': u'CurrencyConvertor',
#     u'soap_uri': u'http://schemas.xmlsoap.org/wsdl/soap12/',
#     u'soap_ver': u'soap12',
#     u'style': None,
#     u'transport': u'http://schemas.xmlsoap.org/soap/http'}}}}

# %%
client.get_operation('ConversionRate')
# Out:
# {u'action': u'http://www.webserviceX.NET/ConversionRate',
#  u'documentation': u"<br><b>Get conversion rate from one currency to another currency <b><br><p><b><font color='#000080' size='1' face='Verdana'><u>Differenct currency Code and Names around the world</u></font></b></p><blockquote><p><font face='Verdana' size='1'>AFA-Afghanistan Afghani<br>ALL-Albanian Lek<br>DZD-Algerian Dinar<br>ARS-Argentine Peso<br>AWG-Aruba Florin<br>AUD-Australian Dollar<br>BSD-Bahamian Dollar<br>BHD-Bahraini Dinar<br>BDT-Bangladesh Taka<br>BBD-Barbados Dollar<br>BZD-Belize Dollar<br>BMD-Bermuda Dollar<br>BTN-Bhutan Ngultrum<br>BOB-Bolivian Boliviano<br>BWP-Botswana Pula<br>BRL-Brazilian Real<br>GBP-British Pound<br>BND-Brunei Dollar<br>BIF-Burundi Franc<br>XOF-CFA Franc (BCEAO)<br>XAF-CFA Franc (BEAC)<br>KHR-Cambodia Riel<br>CAD-Canadian Dollar<br>CVE-Cape Verde Escudo<br>KYD-Cayman Islands Dollar<br>CLP-Chilean Peso<br>CNY-Chinese Yuan<br>COP-Colombian Peso<br>KMF-Comoros Franc<br>CRC-Costa Rica Colon<br>HRK-Croatian Kuna<br>CUP-Cuban Peso<br>CYP-Cyprus Pound<br>CZK-Czech Koruna<br>DKK-Danish Krone<br>DJF-Dijibouti Franc<br>DOP-Dominican Peso<br>XCD-East Caribbean Dollar<br>EGP-Egyptian Pound<br>SVC-El Salvador Colon<br>EEK-Estonian Kroon<br>ETB-Ethiopian Birr<br>EUR-Euro<br>FKP-Falkland Islands Pound<br>GMD-Gambian Dalasi<br>GHC-Ghanian Cedi<br>GIP-Gibraltar Pound<br>XAU-Gold Ounces<br>GTQ-Guatemala Quetzal<br>GNF-Guinea Franc<br>GYD-Guyana Dollar<br>HTG-Haiti Gourde<br>HNL-Honduras Lempira<br>HKD-Hong Kong Dollar<br>HUF-Hungarian Forint<br>ISK-Iceland Krona<br>INR-Indian Rupee<br>IDR-Indonesian Rupiah<br>IQD-Iraqi Dinar<br>ILS-Israeli Shekel<br>JM
#  u'namespace': u'http://www.webserviceX.NET/',
#  u'output': {'ConversionRateResponse': {u'ConversionRateResult': <alias 'double' for '<type 'float'>'>}},
#  u'parameter_order': [u''],
#  u'qualified': True,
#  u'style': None}

# %%
client.ConversionRate(FromCurrency='KPW', ToCurrency='USD')
# Out:
# {'ConversionRateResult': -1.0}

# %% [markdown]
# ![soap_request](soap_request.png)
# ![soap_response](soap_response.png)

# %% [markdown]
# #JSON

# %%
import requests
res = requests.get('http://www.w3schools.com/js/customers_mysql.php')

# %%
res
# Out:
# <Response [200]>

# %%
res.json()
# Out:
# [{u'City': u'Berlin', u'Country': u'Germany', u'Name': u'Alfreds Futterkiste'},
#  {u'City': u'Lule\xe5',
#   u'Country': u'Sweden',
#   u'Name': u'Berglunds snabbk\xf6p'},
#  {u'City': u'M\xe9xico D.F.',
#   u'Country': u'Mexico',
#   u'Name': u'Centro comercial Moctezuma'},
#  {u'City': u'Graz', u'Country': u'Austria', u'Name': u'Ernst Handel'},
#  {u'City': u'Madrid',
#   u'Country': u'Spain',
#   u'Name': u'FISSA Fabrica Inter. Salchichas S.A.'},
#  {u'City': u'Barcelona',
#   u'Country': u'Spain',
#   u'Name': u'Galer\xeda del gastr\xf3nomo'},
#  {u'City': u'Cowes', u'Country': u'UK', u'Name': u'Island Trading'},
#  {u'City': u'Brandenburg',
#   u'Country': u'Germany',
#   u'Name': u'K\xf6niglich Essen'},
#  {u'City': u'Vancouver',
#   u'Country': u'Canada',
#   u'Name': u'Laughing Bacchus Wine Cellars'},
#  {u'City': u'Bergamo',
#   u'Country': u'Italy',
#   u'Name': u'Magazzini Alimentari Riuniti'},
#  {u'City': u'London', u'Country': u'UK', u'Name': u'North/South'},
#  {u'City': u'Paris',
#   u'Country': u'France',
#   u'Name': u'Paris sp\xe9cialit\xe9s'},
#  {u'City': u'Albuquerque',
#   u'Country': u'USA',
#   u'Name': u'Rattlesnake Canyon Grocery'},
#  {u'City': u'K\xf8benhavn', u'Country': u'Denmark', u'Name': u'Simons bistro'},
#  {u'City': u'Portland', u'Country': u'USA', u'Name': u'The Big Cheese'},
#  {u'City': u'\xc5rhus', u'Country': u'Denmark', u'Name': u'Vaffeljernet'},
#  {u'City': u'Warszawa', u'Country': u'Poland', u'Name': u'Wolski Zajazd'}]

# %% [markdown]
# #JSON -> DataFrame

# %%
import pandas as pd

# %%
df = pd.DataFrame(res.json())

# %%
df
# Out:
#            City  Country                                  Name
# 0        Berlin  Germany                   Alfreds Futterkiste
# 1         Luleå   Sweden                    Berglunds snabbköp
# 2   México D.F.   Mexico            Centro comercial Moctezuma
# 3          Graz  Austria                          Ernst Handel
# 4        Madrid    Spain  FISSA Fabrica Inter. Salchichas S.A.
# 5     Barcelona    Spain                Galería del gastrónomo
# 6         Cowes       UK                        Island Trading
# 7   Brandenburg  Germany                       Königlich Essen
# 8     Vancouver   Canada         Laughing Bacchus Wine Cellars
# 9       Bergamo    Italy          Magazzini Alimentari Riuniti
# 10       London       UK                           North/South
# 11        Paris   France                     Paris spécialités
# 12  Albuquerque      USA            Rattlesnake Canyon Grocery
# 13    København  Denmark                         Simons bistro
# 14     Portland      USA                        The Big Cheese
# 15        Århus  Denmark                          Vaffeljernet
# 16     Warszawa   Poland                         Wolski Zajazd

# %% [markdown]
# #Appendix

# %%
import requests
import bs4 as soup
import pandas as pd

# %%
zb = requests.get('https://api.zigbang.com/v2/items?lat_south=37.469666050690506&lat_north=37.610794673200786&lng_west=127.03400360696608&lng_east=127.045846503341&room=01;02;03;04;05')
zbdatalist = soup.BeautifulSoup(zb.text)
json_zb = zb.json()
json_zb
# Out:
# {u'list_items': [{u'position': 0,
#    u'section_type': u'premium_recommand',
#    u'simple_item': {u'item_id': 6243828}},
#   {u'position': 1,
#    u'section_type': u'premium_recommand',
#    u'simple_item': {u'item_id': 6092255}},
#   {u'position': 2,
#    u'section_type': u'premium_recommand',
#    u'simple_item': {u'item_id': 6234041}},
#   {u'position': 3,
#    u'section_type': u'premium_recommand',
#    u'simple_item': {u'item_id': 6131076}},
#   {u'position': 4,
#    u'section_type': u'premium_recommand',
#    u'simple_item': {u'item_id': 6247948}},
#   {u'position': 5,
#    u'section_type': u'premium_recommand',
#    u'simple_item': {u'item_id': 6095930}},
#   {u'position': 6,
#    u'section_type': u'premium_recommand',
#    u'simple_item': {u'item_id': 6335700}},
#   {u'position': 7,
#    u'section_type': u'premium_recommand',
#    u'simple_item': {u'item_id': 6288279}},
#   {u'position': 8,
#    u'section_type': u'premium_recommand',
#    u'simple_item': {u'item_id': 6307000}},
#   {u'position': 9,
#    u'section_type': u'premium_recommand',
#    u'simple_item': {u'item_id': 6310347}},
#   {u'position': 10,
#    u'section_type': u'premium_recommand',
#    u'simple_item': {u'item_id': 6297817}},
#   {u'position': 11,
#    u'section_type': u'premium_recommand',
#    u'simple_item': {u'item_id': 6321776}},
#   {u'position': 12,
#    u'section_type': u'premium_recommand',
#    u'simple_item': {u'item_id': 6117373}},
#   {u'position': 13,
#    u'section_type': u'premium_recommand',
#    u'simple_item': {u'item_id': 6198915}},
#   {u'position': 14,
#    u'section_type': u'premium_recommand',
#    u'simple_item': {u'item_id': 6311600}},
#   {u'position': 15,
#    u'section_type': u'premium_recommand',
#    u'simple_item': {u'item_id': 6317695}},
#   {u'position': 16,
#    u'section_type': u'premium_recommand',
#    u'simple_item': {u'item_id': 6321082}},
#   {u'position': 17,
#    u'section_type': u'premium_recommand',
#    u'simple_item': {u'item_id': 6279777}},
#   {u'position': 18,
#    u'section_type': u'premium_recommand',
#    u'simple_item': {u'item_id': 6308314}},
#   {u'position': 19,
#    u'section_type': u'premium_recommand',
#    u'simple_item': {u'item_id': 6186174}},
#   {u'position': 20,
#    u'section_type': u'premium_recommand',
#    u'simple_item': {u'item_id': 6315400}},
#   {u'position': 21,
#    u'section_type': u'premium_recommand',
#    u'simple_item': {u'item_id': 6297924}},
#   {u'position': 22,
#    u'section_type': u'premium_recommand',
#    u'simple_item': {u'item_id': 6333067}},
#   {u'position': 23,
#    u'section_type': u'premium_recommand',
#    u'simple_item': {u'item_id': 6322273}},
#   {u'position': 24,
#    u'section_type': u'premium_recommand',
#    u'simple_item': {u'item_id': 6292964}},
#   {u'position': 25,
#    u'section_type': u'premium_recommand',
#    u'simple_item': {u'item_id': 6264607}},
#   {u'position': 26,
#    u'section_type': u'premium_recommand',
#    u'simple_item': {u'item_id': 6309715}},
#   {u'position': 27,
#    u'section_type': u'premium_recommand',
#    u'simple_item': {u'item_id': 6314314}},
#   {u'position': 28,
#    u'section_type': u'premium_recommand',
#    u'simple_item': {u'item_id': 6278836}},
#   {u'position': 29,
#    u'section_type': u'premium_recommand',
#    u'simple_item': {u'item_id': 6317582}},
#   {u'position': 30,
#    u'section_type': u'premium_recommand',
#    u'simple_item': {u'item_id': 6242165}},
#   {u'position': 31,
#    u'section_type': u'premium_recommand',
#    u'simple_item': {u'item_id': 6224103}},
#   {u'position': 32,
#    u'section_type': u'premium_recommand',
#    u'simple_item': {u'item_id': 6322244}},
#   {u'position': 33,
#    u'section_type': u'premium_recommand',
#    u'simple_item': {u'item_id': 6302458}},
#   {u'position': 34,
#    u'section_type': u'premium_recommand',
#    u'simple_item': {u'item_id': 6291888}},
#   {u'position': 35,
#    u'section_type': u'premium_recommand',
#    u'simple_item': {u'item_id': 6227338}},
#   {u'position': 36,
#    u'section_type': u'premium_recommand',
#    u'simple_item': {u'item_id': 6219018}},
#   {u'position': 37,
#    u'section_type': u'premium_recommand',
#    u'simple_item': {u'item_id': 6262534}},
#   {u'position': 38,
#    u'section_type': u'premium_recommand',
#    u'simple_item': {u'item_id': 6310597}},
#   {u'position': 39,
#    u'section_type': u'premium_recommand',
#    u'simple_item': {u'item_id': 6323428}},
#   {u'position': 40,
#    u'section_type': u'premium_recommand',
#    u'simple_item': {u'item_id': 6265892}},
#   {u'position': 41,
#    u'section_type': u'premium_recommand',
#    u'simple_item': {u'item_id': 6322512}},
#   {u'position': 42,
#    u'section_type': u'premium_recommand',
#    u'simple_item': {u'item_id': 6311606}},
#   {u'position': 43,
#    u'section_type': u'premium_recommand',
#    u'simple_item': {u'item_id': 6313078}},
#   {u'position': 44,
#    u'section_type': u'premium_recommand',
#    u'simple_item': {u'item_id': 6292917}},
#   {u'position': 45,
#    u'section_type': u'premium_recommand',
#    u'simple_item': {u'item_id': 6282456}},
#   {u'position': 46,
#    u'section_type': u'premium_recommand',
#    u'simple_item': {u'item_id': 6312301}},
#   {u'position': 47,
#    u'section_type': u'premium_recommand',
#    u'simple_item': {u'item_id': 6172290}},
#   {u'position': 48,
#    u'section_type': u'premium_recommand',
#    u'simple_item': {u'item_id': 6310232}},
#   {u'position': 49,
#    u'section_type': u'premium_recommand',
#    u'simple_item': {u'item_id': 6327831}},
#   {u'position': 50,
#    u'section_type': u'premium_recommand',
#    u'simple_item': {u'item_id': 6319483}},
#   {u'position': 51,
#    u'section_type': u'premium_recommand',
#    u'simple_item': {u'item_id': 6316514}},
#   {u'position': 52,
#    u'section_type': u'premium_recommand',
#    u'simple_item': {u'item_id': 6333564}},
#   {u'position': 53,
#    u'section_type': u'premium_recommand',
#    u'simple_item': {u'item_id': 6286330}},
#   {u'position': 54,
#    u'section_type': u'premium_recommand',
#    u'simple_item': {u'item_id': 6139233}},
#   {u'position': 55,
#    u'section_type': u'premium_recommand',
#    u'simple_item': {u'item_id': 6216811}},
#   {u'position': 56,
#    u'section_type': u'premium_recommand',
#    u'simple_item': {u'item_id': 6221536}},
#   {u'position': 57,
#    u'section_type': u'premium_recommand',
#    u'simple_item': {u'item_id': 6317497}},
#   {u'position': 58,
#    u'section_type': u'premium_recommand',
#    u'simple_item': {u'item_id': 6315830}},
#   {u'position': 59,
#    u'section_type': u'premium_recommand',
#    u'simple_item': {u'item_id': 6281161}},
#   {u'position': 60,
#    u'section_type': u'premium_recommand',
#    u'simple_item': {u'item_id': 6231911}},
#   {u'position': 61,
#    u'section_type': u'premium_recommand',
#    u'simple_item': {u'item_id': 6240929}},
#   {u'position': 62,
#    u'section_type': u'premium_recommand',
#    u'simple_item': {u'item_id': 6307003}},
#   {u'position': 63,
#    u'section_type': u'premium_recommand',
#    u'simple_item': {u'item_id': 6198235}},
#   {u'position': 64,
#    u'section_type': u'premium_recommand',
#    u'simple_item': {u'item_id': 6335296}},
#   {u'position': 65,
#    u'section_type': u'premium_recommand',
#    u'simple_item': {u'item_id': 6334486}},
#   {u'position': 66,
#    u'section_type': u'premium_recommand',
#    u'simple_item': {u'item_id': 6336662}},
#   {u'position': 67,
#    u'section_type': u'premium_recommand',
#    u'simple_item': {u'item_id': 6271826}},
#   {u'position': 68,
#    u'section_type': u'premium_recommand',
#    u'simple_item': {u'item_id': 6245047}},
#   {u'position': 69,
#    u'section_type': u'premium_recommand',
#    u'simple_item': {u'item_id': 6320979}},
#   {u'position': 70,
#    u'section_type': u'premium_recommand',
#    u'simple_item': {u'item_id': 6314055}},
#   {u'position': 71,
#    u'section_type': u'premium_recommand',
#    u'simple_item': {u'item_id': 6218696}},
#   {u'position': 72,
#    u'section_type': u'premium_recommand',
#    u'simple_item': {u'item_id': 6311814}},
#   {u'position': 73,
#    u'section_type': u'premium_recommand',
#    u'simple_item': {u'item_id': 6176579}},
#   {u'position': 74,
#    u'section_type': u'premium_recommand',
#    u'simple_item': {u'item_id': 6242654}},
#   {u'position': 75,
#    u'section_type': u'premium_recommand',
#    u'simple_item': {u'item_id': 6166604}},
#   {u'position': 76,
#    u'section_type': u'premium_recommand',
#    u'simple_item': {u'item_id': 6320430}},
#   {u'position': 77,
#    u'section_type': u'premium_recommand',
#    u'simple_item': {u'item_id': 6281960}},
#   {u'position': 78,
#    u'section_type': u'premium_recommand',
#    u'simple_item': {u'item_id': 6292389}},
#   {u'position': 79,
#    u'section_type': u'premium_recommand',
#    u'simple_item': {u'item_id': 6154720}},
#   {u'position': 80,
#    u'section_type': u'premium_recommand',
#    u'simple_item': {u'item_id': 6312456}},
#   {u'position': 81,
#    u'section_type': u'premium_recommand',
#    u'simple_item': {u'item_id': 6297923}},
#   {u'position': 82,
#    u'section_type': u'premium_recommand',
#    u'simple_item': {u'item_id': 6251086}},
#   {u'position': 83,
#    u'section_type': u'premium_recommand',
#    u'simple_item': {u'item_id': 6252336}},
#   {u'position': 84,
#    u'section_type': u'premium_recommand',
#    u'simple_item': {u'item_id': 6263153}},
#   {u'position': 85,
#    u'section_type': u'premium_recommand',
#    u'simple_item': {u'item_id': 6312780}},
#   {u'position': 86,
#    u'section_type': u'premium_recommand',
#    u'simple_item': {u'item_id': 6318609}},
#   {u'position': 87,
#    u'section_type': u'premium_recommand',
#    u'simple_item': {u'item_id': 5881716}},
#   {u'position': 88,
#    u'section_type': u'premium_recommand',
#    u'simple_item': {u'item_id': 6166709}},
#   {u'position': 89,
#    u'section_type': u'premium_recommand',
#    u'simple_item': {u'item_id': 6317361}},
#   {u'position': 90,
#    u'section_type': u'premium_recommand',
#    u'simple_item': {u'item_id': 6300986}},
#   {u'position': 91,
#    u'section_type': u'premium_recommand',
#    u'simple_item': {u'item_id': 6276263}},
#   {u'position': 92,
#    u'section_type': u'premium_recommand',
#    u'simple_item': {u'item_id': 6122565}},
#   {u'position': 93,
#    u'section_type': u'premium_recommand',
#    u'simple_item': {u'item_id': 6280490}},
#   {u'position': 94,
#    u'section_type': u'premium_recommand',
#    u'simple_item': {u'item_id': 6139999}},
#   {u'position': 95,
#    u'section_type': u'premium_recommand',
#    u'simple_item': {u'item_id': 6076769}},
#   {u'position': 96,
#    u'section_type': u'premium_recommand',
#    u'simple_item': {u'item_id': 6262735}},
#   {u'position': 97,
#    u'section_type': u'premium_recommand',
#    u'simple_item': {u'item_id': 6203380}},
#   {u'position': 98,
#    u'section_type': u'premium_recommand',
#    u'simple_item': {u'item_id': 6288790}},
#   {u'position': 99,
#    u'section_type': u'premium_recommand',
#    u'simple_item': {u'item_id': 6289298}},
#   {u'position': 100,
#    u'section_type': u'premium_recommand',
#    u'simple_item': {u'item_id': 6182156}},
#   {u'position': 101,
#    u'section_type': u'premium_recommand',
#    u'simple_item': {u'item_id': 6325104}},
#   {u'position': 102,
#    u'section_type': u'premium_recommand',
#    u'simple_item': {u'item_id': 6323483}},
#   {u'position': 103,
#    u'section_type': u'premium_recommand',
#    u'simple_item': {u'item_id': 6282247}},
#   {u'position': 104,
#    u'section_type': u'premium_recommand',
#    u'simple_item': {u'item_id': 6151102}},
#   {u'position': 105,
#    u'section_type': u'premium_recommand',
#    u'simple_item': {u'item_id': 6179851}},
#   {u'position': 106,
#    u'section_type': u'premium_recommand',
#    u'simple_item': {u'item_id': 6295214}},
#   {u'position': 107,
#    u'section_type': u'premium_recommand',
#    u'simple_item': {u'item_id': 6262975}},
#   {u'position': 108,
#    u'section_type': u'premium_recommand',
#    u'simple_item': {u'item_id': 6324923}},
#   {u'position': 109,
#    u'section_type': u'premium_recommand',
#    u'simple_item': {u'item_id': 6039098}},
#   {u'position': 110,
#    u'section_type': u'premium_recommand',
#    u'simple_item': {u'item_id': 6288489}},
#   {u'position': 111,
#    u'section_type': u'premium_recommand',
#    u'simple_item': {u'item_id': 6278306}},
#   {u'position': 112,
#    u'section_type': u'premium_recommand',
#    u'simple_item': {u'item_id': 6159454}},
#   {u'position': 113,
#    u'section_type': u'premium_recommand',
#    u'simple_item': {u'item_id': 6304055}},
#   {u'position': 114,
#    u'section_type': u'premium_recommand',
#    u'simple_item': {u'item_id': 6309006}},
#   {u'position': 115,
#    u'section_type': u'premium_recommand',
#    u'simple_item': {u'item_id': 5503204}},
#   {u'position': 116,
#    u'section_type': u'premium_recommand',
#    u'simple_item': {u'item_id': 6312728}},
#   {u'position': 117,
#    u'section_type': u'premium_recommand',
#    u'simple_item': {u'item_id': 6160789}},
#   {u'position': 118,
#    u'section_type': u'premium_recommand',
#    u'simple_item': {u'item_id': 6332908}},
#   {u'position': 119,
#    u'section_type': u'premium_recommand',
#    u'simple_item': {u'item_id': 6329960}},
#   {u'position': 120,
#    u'section_type': u'premium_recommand',
#    u'simple_item': {u'item_id': 6319488}},
#   {u'position': 121,
#    u'section_type': u'premium_recommand',
#    u'simple_item': {u'item_id': 6315648}},
#   {u'position': 122,
#    u'section_type': u'premium_recommand',
#    u'simple_item': {u'item_id': 6304592}},
#   {u'position': 123,
#    u'section_type': u'premium_recommand',
#    u'simple_item': {u'item_id': 6191973}},
#   {u'position': 124,
#    u'section_type': u'premium_recommand',
#    u'simple_item': {u'item_id': 6318856}},
#   {u'position': 125,
#    u'section_type': u'premium_recommand',
#    u'simple_item': {u'item_id': 6120540}},
#   {u'position': 126,
#    u'section_type': u'premium_recommand',
#    u'simple_item': {u'item_id': 6259020}},
#   {u'position': 127,
#    u'section_type': u'premium_recommand',
#    u'simple_item': {u'item_id': 5970493}},
#   {u'position': 128,
#    u'section_type': u'premium_recommand',
#    u'simple_item': {u'item_id': 6222734}},
#   {u'position': 129,
#    u'section_type': u'premium_recommand',
#    u'simple_item': {u'item_id': 6241488}},
#   {u'position': 130,
#    u'section_type': u'premium_recommand',
#    u'simple_item': {u'item_id': 6271319}},
#   {u'position': 131,
#    u'section_type': u'premium_recommand',
#    u'simple_item': {u'item_id': 6179529}},
#   {u'position': 132,
#    u'section_type': u'premium_recommand',
#    u'simple_item': {u'item_id': 6317020}},
#   {u'position': 133,
#    u'section_type': u'premium_recommand',
#    u'simple_item': {u'item_id': 6318895}},
#   {u'position': 134,
#    u'section_type': u'premium_recommand',
#    u'simple_item': {u'item_id': 6288094}},
#   {u'position': 135,
#    u'section_type': u'premium_recommand',
#    u'simple_item': {u'item_id': 6241481}},
#   {u'position': 136,
#    u'section_type': u'premium_recommand',
#    u'simple_item': {u'item_id': 6326623}},
#   {u'position': 137,
#    u'section_type': u'premium_recommand',
#    u'simple_item': {u'item_id': 6209959}},
#   {u'position': 138,
#    u'section_type': u'premium_recommand',
#    u'simple_item': {u'item_id': 6304940}},
#   {u'position': 139,
#    u'section_type': u'premium_recommand',
#    u'simple_item': {u'item_id': 6250669}},
#   {u'position': 140,
#    u'section_type': u'premium_recommand',
#    u'simple_item': {u'item_id': 6166151}},
#   {u'position': 141,
#    u'section_type': u'premium_recommand',
#    u'simple_item': {u'item_id': 6205794}},
#   {u'position': 142,
#    u'section_type': u'premium_recommand',
#    u'simple_item': {u'item_id': 6277868}},
#   {u'position': 143,
#    u'section_type': u'premium_recommand',
#    u'simple_item': {u'item_id': 6222666}},
#   {u'position': 144,
#    u'section_type': u'premium_recommand',
#    u'simple_item': {u'item_id': 6316529}},
#   {u'position': 145,
#    u'section_type': u'premium_recommand',
#    u'simple_item': {u'item_id': 6200301}},
#   {u'position': 146,
#    u'section_type': u'premium_recommand',
#    u'simple_item': {u'item_id': 6309898}},
#   {u'position': 147,
#    u'section_type': u'premium_recommand',
#    u'simple_item': {u'item_id': 6335703}},
#   {u'position': 148,
#    u'section_type': u'premium_recommand',
#    u'simple_item': {u'item_id': 6230916}},
#   {u'position': 149,
#    u'section_type': u'premium_recommand',
#    u'simple_item': {u'item_id': 6327517}},
#   {u'position': 150,
#    u'section_type': u'premium_recommand',
#    u'simple_item': {u'item_id': 6322576}},
#   {u'position': 151,
#    u'section_type': u'premium_recommand',
#    u'simple_item': {u'item_id': 5764626}},
#   {u'position': 152,
#    u'section_type': u'premium_recommand',
#    u'simple_item': {u'item_id': 6298585}},
#   {u'position': 153,
#    u'section_type': u'premium_recommand',
#    u'simple_item': {u'item_id': 6054954}},
#   {u'position': 154,
#    u'section_type': u'premium_recommand',
#    u'simple_item': {u'item_id': 6307813}},
#   {u'position': 155,
#    u'section_type': u'premium_recommand',
#    u'simple_item': {u'item_id': 6284852}},
#   {u'position': 156,
#    u'section_type': u'premium_recommand',
#    u'simple_item': {u'item_id': 6257496}},
#   {u'position': 157,
#    u'section_type': u'premium_recommand',
#    u'simple_item': {u'item_id': 6182091}},
#   {u'position': 158,
#    u'section_type': u'premium_recommand',
#    u'simple_item': {u'item_id': 6262346}},
#   {u'position': 159,
#    u'section_type': u'premium_recommand',
#    u'simple_item': {u'item_id': 6248061}},
#   {u'position': 160,
#    u'section_type': u'premium_recommand',
#    u'simple_item': {u'item_id': 6241791}},
#   {u'position': 161,
#    u'section_type': u'premium_recommand',
#    u'simple_item': {u'item_id': 6222529}},
#   {u'position': 162,
#    u'section_type': u'premium_recommand',
#    u'simple_item': {u'item_id': 6336105}},
#   {u'position': 163,
#    u'section_type': u'premium_recommand',
#    u'simple_item': {u'item_id': 6052937}},
#   {u'position': 164,
#    u'section_type': u'premium_recommand',
#    u'simple_item': {u'item_id': 6262174}},
#   {u'position': 165,
#    u'section_type': u'premium_recommand',
#    u'simple_item': {u'item_id': 6001505}},
#   {u'position': 166,
#    u'section_type': u'premium_recommand',
#    u'simple_item': {u'item_id': 6122111}},
#   {u'position': 167,
#    u'section_type': u'premium_recommand',
#    u'simple_item': {u'item_id': 6175626}},
#   {u'position': 168,
#    u'section_type': u'premium_recommand',
#    u'simple_item': {u'item_id': 6288534}},
#   {u'position': 169,
#    u'section_type': u'premium_recommand',
#    u'simple_item': {u'item_id': 6291945}},
#   {u'position': 170,
#    u'section_type': u'premium_recommand',
#    u'simple_item': {u'item_id': 6201697}},
#   {u'position': 171,
#    u'section_type': u'premium_recommand',
#    u'simple_item': {u'item_id': 6070988}},
#   {u'position': 172,
#    u'section_type': u'premium_recommand',
#    u'simple_item': {u'item_id': 6266965}},
#   {u'position': 173,
#    u'section_type': u'premium_recommand',
#    u'simple_item': {u'item_id': 6126815}},
#   {u'position': 174,
#    u'section_type': u'premium_recommand',
#    u'simple_item': {u'item_id': 6308225}},
#   {u'position': 175,
#    u'section_type': u'premium_recommand',
#    u'simple_item': {u'item_id': 6190562}},
#   {u'position': 176,
#    u'section_type': u'premium_recommand',
#    u'simple_item': {u'item_id': 6317097}},
#   {u'position': 177,
#    u'section_type': u'premium_recommand',
#    u'simple_item': {u'item_id': 6240515}},
#   {u'position': 178,
#    u'section_type': u'premium_recommand',
#    u'simple_item': {u'item_id': 6219111}},
#   {u'position': 179,
#    u'section_type': u'premium_recommand',
#    u'simple_item': {u'item_id': 6216257}},
#   {u'position': 180,
#    u'section_type': u'premium_recommand',
#    u'simple_item': {u'item_id': 6283502}},
#   {u'position': 181,
#    u'section_type': u'premium_recommand',
#    u'simple_item': {u'item_id': 6178923}},
#   {u'position': 182,
#    u'section_type': u'premium_recommand',
#    u'simple_item': {u'item_id': 5914053}},
#   {u'position': 183,
#    u'section_type': u'premium_recommand',
#    u'simple_item': {u'item_id': 6335490}},
#   {u'position': 184,
#    u'section_type': u'premium_recommand',
#    u'simple_item': {u'item_id': 6240526}},
#   {u'position': 185,
#    u'section_type': u'premium_recommand',
#    u'simple_item': {u'item_id': 6330515}},
#   {u'position': 186,
#    u'section_type': u'premium_recommand',
#    u'simple_item': {u'item_id': 6335831}},
#   {u'position': 187,
#    u'section_type': u'premium_recommand',
#    u'simple_item': {u'item_id': 6261597}},
#   {u'position': 188,
#    u'section_type': u'premium_recommand',
#    u'simple_item': {u'item_id': 6247051}},
#   {u'position': 189,
#    u'section_type': u'premium_recommand',
#    u'simple_item': {u'item_id': 6086440}},
#   {u'position': 190,
#    u'section_type': u'premium_recommand',
#    u'simple_item': {u'item_id': 6326686}},
#   {u'position': 191,
#    u'section_type': u'premium_recommand',
#    u'simple_item': {u'item_id': 5652943}},
#   {u'position': 192,
#    u'section_type': u'premium_recommand',
#    u'simple_item': {u'item_id': 6182298}},
#   {u'position': 193,
#    u'section_type': u'premium_recommand',
#    u'simple_item': {u'item_id': 6258483}},
#   {u'position': 194,
#    u'section_type': u'premium_recommand',
#    u'simple_item': {u'item_id': 6224688}},
#   {u'position': 195,
#    u'section_type': u'premium_recommand',
#    u'simple_item': {u'item_id': 6188561}},
#   {u'position': 196,
#    u'section_type': u'premium_recommand',
#    u'simple_item': {u'item_id': 6219167}},
#   {u'position': 197,
#    u'section_type': u'premium_recommand',
#    u'simple_item': {u'item_id': 6314170}},
#   {u'position': 198,
#    u'section_type': u'premium_recommand',
#    u'simple_item': {u'item_id': 6241125}},
#   {u'position': 199,
#    u'section_type': u'premium_recommand',
#    u'simple_item': {u'item_id': 6150424}},
#   {u'position': 200,
#    u'section_type': u'premium_recommand',
#    u'simple_item': {u'item_id': 6310606}},
#   {u'position': 201,
#    u'section_type': u'premium_recommand',
#    u'simple_item': {u'item_id': 6336659}},
#   {u'position': 202,
#    u'section_type': u'premium_recommand',
#    u'simple_item': {u'item_id': 6179678}},
#   {u'position': 203,
#    u'section_type': u'premium_recommand',
#    u'simple_item': {u'item_id': 6298272}},
#   {u'position': 204,
#    u'section_type': u'premium_recommand',
#    u'simple_item': {u'item_id': 6293844}},
#   {u'position': 205,
#    u'section_type': u'premium_recommand',
#    u'simple_item': {u'item_id': 6064137}},
#   {u'position': 206,
#    u'section_type': u'premium_recommand',
#    u'simple_item': {u'item_id': 6139641}},
#   {u'position': 207,
#    u'section_type': u'premium_recommand',
#    u'simple_item': {u'item_id': 6314046}},
#   {u'position': 208,
#    u'section_type': u'premium_recommand',
#    u'simple_item': {u'item_id': 6314059}},
#   {u'position': 209,
#    u'section_type': u'premium_recommand',
#    u'simple_item': {u'item_id': 6222759}},
#   {u'position': 210,
#    u'section_type': u'premium_recommand',
#    u'simple_item': {u'item_id': 6329386}},
#   {u'position': 211,
#    u'section_type': u'premium_recommand',
#    u'simple_item': {u'item_id': 6242584}},
#   {u'position': 212,
#    u'section_type': u'premium_recommand',
#    u'simple_item': {u'item_id': 6254895}},
#   {u'position': 213,
#    u'section_type': u'premium_recommand',
#    u'simple_item': {u'item_id': 6194266}},
#   {u'position': 214,
#    u'section_type': u'premium_recommand',
#    u'simple_item': {u'item_id': 6315640}},
#   {u'position': 215,
#    u'section_type': u'premium_recommand',
#    u'simple_item': {u'item_id': 6206349}},
#   {u'position': 216,
#    u'section_type': u'premium_recommand',
#    u'simple_item': {u'item_id': 6295242}},
#   {u'position': 217,
#    u'section_type': u'premium_recommand',
#    u'simple_item': {u'item_id': 6262293}},
#   {u'position': 218,
#    u'section_type': u'premium_recommand',
#    u'simple_item': {u'item_id': 5933766}},
#   {u'position': 219,
#    u'section_type': u'premium_recommand',
#    u'simple_item': {u'item_id': 6292621}},
#   {u'position': 220,
#    u'section_type': u'premium_recommand',
#    u'simple_item': {u'item_id': 5963510}},
#   {u'position': 221,
#    u'section_type': u'premium_recommand',
#    u'simple_item': {u'item_id': 6318903}},
#   {u'position': 222,
#    u'section_type': u'premium_recommand',
#    u'simple_item': {u'item_id': 6310903}},
#   {u'position': 223,
#    u'section_type': u'premium_recommand',
#    u'simple_item': {u'item_id': 6191299}},
#   {u'position': 224,
#    u'section_type': u'premium_recommand',
#    u'simple_item': {u'item_id': 6133385}},
#   {u'position': 225,
#    u'section_type': u'premium_recommand',
#    u'simple_item': {u'item_id': 6231157}},
#   {u'position': 226,
#    u'section_type': u'premium_recommand',
#    u'simple_item': {u'item_id': 6201923}},
#   {u'position': 227,
#    u'section_type': u'premium_recommand',
#    u'simple_item': {u'item_id': 6310625}},
#   {u'position': 228,
#    u'section_type': u'premium_recommand',
#    u'simple_item': {u'item_id': 6038246}},
#   {u'position': 229,
#    u'section_type': u'premium_recommand',
#    u'simple_item': {u'item_id': 6312617}},
#   {u'position': 230,
#    u'section_type': u'premium_recommand',
#    u'simple_item': {u'item_id': 6334484}},
#   {u'position': 231,
#    u'section_type': u'premium_recommand',
#    u'simple_item': {u'item_id': 6252241}},
#   {u'position': 232,
#    u'section_type': u'premium_recommand',
#    u'simple_item': {u'item_id': 6335996}},
#   {u'position': 233,
#    u'section_type': u'premium_recommand',
#    u'simple_item': {u'item_id': 6319456}},
#   {u'position': 234,
#    u'section_type': u'premium_recommand',
#    u'simple_item': {u'item_id': 5797049}},
#   {u'position': 235,
#    u'section_type': u'premium_recommand',
#    u'simple_item': {u'item_id': 6259376}},
#   {u'position': 236,
#    u'section_type': u'premium_recommand',
#    u'simple_item': {u'item_id': 6312323}},
#   {u'position': 237,
#    u'section_type': u'premium_recommand',
#    u'simple_item': {u'item_id': 6198984}},
#   {u'position': 238,
#    u'section_type': u'premium_recommand',
#    u'simple_item': {u'item_id': 6255773}},
#   {u'position': 239,
#    u'section_type': u'premium_recommand',
#    u'simple_item': {u'item_id': 6181974}},
#   {u'position': 240,
#    u'section_type': u'premium_recommand',
#    u'simple_item': {u'item_id': 6245492}},
#   {u'position': 241,
#    u'section_type': u'premium_recommand',
#    u'simple_item': {u'item_id': 6085854}},
#   {u'position': 242,
#    u'section_type': u'premium_recommand',
#    u'simple_item': {u'item_id': 6332494}},
#   {u'position': 243,
#    u'section_type': u'premium_recommand',
#    u'simple_item': {u'item_id': 6325483}},
#   {u'position': 244,
#    u'section_type': u'premium_recommand',
#    u'simple_item': {u'item_id': 6329371}},
#   {u'position': 245,
#    u'section_type': u'premium_recommand',
#    u'simple_item': {u'item_id': 6176934}},
#   {u'position': 246,
#    u'section_type': u'premium_recommand',
#    u'simple_item': {u'item_id': 6310444}},
#   {u'position': 247,
#    u'section_type': u'premium_recommand',
#    u'simple_item': {u'item_id': 6305253}},
#   {u'position': 248,
#    u'section_type': u'premium_recommand',
#    u'simple_item': {u'item_id': 6324899}},
#   {u'position': 249,
#    u'section_type': u'premium_recommand',
#    u'simple_item': {u'item_id': 6266210}},
#   {u'position': 250,
#    u'section_type': u'premium_recommand',
#    u'simple_item': {u'item_id': 6243208}},
#   {u'position': 251,
#    u'section_type': u'premium_recommand',
#    u'simple_item': {u'item_id': 6221166}},
#   {u'position': 252,
#    u'section_type': u'premium_recommand',
#    u'simple_item': {u'item_id': 6312080}},
#   {u'position': 253,
#    u'section_type': u'premium_recommand',
#    u'simple_item': {u'item_id': 6320187}},
#   {u'position': 254,
#    u'section_type': u'premium_recommand',
#    u'simple_item': {u'item_id': 6327855}},
#   {u'position': 255,
#    u'section_type': u'premium_recommand',
#    u'simple_item': {u'item_id': 6284604}},
#   {u'position': 256,
#    u'section_type': u'premium_recommand',
#    u'simple_item': {u'item_id': 6160717}},
#   {u'position': 257,
#    u'section_type': u'premium_recommand',
#    u'simple_item': {u'item_id': 6202194}},
#   {u'position': 258,
#    u'section_type': u'premium_recommand',
#    u'simple_item': {u'item_id': 6303201}},
#   {u'position': 259,
#    u'section_type': u'premium_recommand',
#    u'simple_item': {u'item_id': 6295199}},
#   {u'position': 260,
#    u'section_type': u'premium_recommand',
#    u'simple_item': {u'item_id': 6224700}},
#   {u'position': 261,
#    u'section_type': u'premium_recommand',
#    u'simple_item': {u'item_id': 6324799}},
#   {u'position': 262,
#    u'section_type': u'premium_recommand',
#    u'simple_item': {u'item_id': 6264623}},
#   {u'position': 263,
#    u'section_type': u'premium_recommand',
#    u'simple_item': {u'item_id': 6284379}},
#   {u'position': 264,
#    u'section_type': u'premium_recommand',
#    u'simple_item': {u'item_id': 6076740}},
#   {u'position': 265,
#    u'section_type': u'premium_recommand',
#    u'simple_item': {u'item_id': 6324575}},
#   {u'position': 266,
#    u'section_type': u'premium_recommand',
#    u'simple_item': {u'item_id': 6216634}},
#   {u'position': 267,
#    u'section_type': u'premium_recommand',
#    u'simple_item': {u'item_id': 6331495}},
#   {u'position': 268,
#    u'section_type': u'premium_recommand',
#    u'simple_item': {u'item_id': 6059513}},
#   {u'position': 269,
#    u'section_type': u'premium_recommand',
#    u'simple_item': {u'item_id': 6184921}},
#   {u'position': 270,
#    u'section_type': u'premium_recommand',
#    u'simple_item': {u'item_id': 6240793}},
#   {u'position': 271,
#    u'section_type': u'premium_recommand',
#    u'simple_item': {u'item_id': 6245604}},
#   {u'position': 272,
#    u'section_type': u'premium_recommand',
#    u'simple_item': {u'item_id': 6334049}},
#   {u'position': 273,
#    u'section_type': u'premium_recommand',
#    u'simple_item': {u'item_id': 6210002}},
#   {u'position': 274,
#    u'section_type': u'premium_recommand',
#    u'simple_item': {u'item_id': 6250885}},
#   {u'position': 275,
#    u'section_type': u'premium_recommand',
#    u'simple_item': {u'item_id': 6311468}},
#   {u'position': 276,
#    u'section_type': u'premium_recommand',
#    u'simple_item': {u'item_id': 6123027}},
#   {u'position': 277,
#    u'section_type': u'premium_recommand',
#    u'simple_item': {u'item_id': 6202648}},
#   {u'position': 278,
#    u'section_type': u'premium_recommand',
#    u'simple_item': {u'item_id': 6322662}},
#   {u'position': 279,
#    u'section_type': u'premium_recommand',
#    u'simple_item': {u'item_id': 6264680}},
#   {u'position': 280,
#    u'section_type': u'premium_recommand',
#    u'simple_item': {u'item_id': 6116714}},
#   {u'position': 281,
#    u'section_type': u'premium_recommand',
#    u'simple_item': {u'item_id': 6310201}},
#   {u'position': 282,
#    u'section_type': u'premium_recommand',
#    u'simple_item': {u'item_id': 6299161}},
#   {u'position': 283,
#    u'section_type': u'premium_recommand',
#    u'simple_item': {u'item_id': 6322703}},
#   {u'position': 284,
#    u'section_type': u'premium_recommand',
#    u'simple_item': {u'item_id': 6321345}},
#   {u'position': 285,
#    u'section_type': u'premium_recommand',
#    u'simple_item': {u'item_id': 6327980}},
#   {u'position': 286,
#    u'section_type': u'premium_recommand',
#    u'simple_item': {u'item_id': 6295907}},
#   {u'position': 287,
#    u'section_type': u'premium_recommand',
#    u'simple_item': {u'item_id': 6293292}},
#   {u'position': 288,
#    u'section_type': u'premium_recommand',
#    u'simple_item': {u'item_id': 6316244}},
#   {u'position': 289,
#    u'section_type': u'premium_recommand',
#    u'simple_item': {u'item_id': 6296612}},
#   {u'position': 290,
#    u'section_type': u'premium_recommand',
#    u'simple_item': {u'item_id': 6336192}},
#   {u'position': 291,
#    u'section_type': u'premium_recommand',
#    u'simple_item': {u'item_id': 6151677}},
#   {u'position': 292,
#    u'section_type': u'premium_recommand',
#    u'simple_item': {u'item_id': 6144256}},
#   {u'position': 293,
#    u'section_type': u'premium_recommand',
#    u'simple_item': {u'item_id': 6268371}},
#   {u'position': 294,
#    u'section_type': u'premium_recommand',
#    u'simple_item': {u'item_id': 6223532}},
#   {u'position': 295,
#    u'section_type': u'premium_recommand',
#    u'simple_item': {u'item_id': 6299388}},
#   {u'position': 296,
#    u'section_type': u'premium_recommand',
#    u'simple_item': {u'item_id': 6305819}},
#   {u'position': 297,
#    u'section_type': u'premium_recommand',
#    u'simple_item': {u'item_id': 4888462}},
#   {u'position': 298,
#    u'section_type': u'premium_recommand',
#    u'simple_item': {u'item_id': 5946551}},
#   {u'position': 299,
#    u'section_type': u'premium_recommand',
#    u'simple_item': {u'item_id': 6315436}},
#   {u'position': 300,
#    u'section_type': u'premium_recommand',
#    u'simple_item': {u'item_id': 6332739}},
#   {u'position': 301,
#    u'section_type': u'premium_recommand',
#    u'simple_item': {u'item_id': 6272571}},
#   {u'position': 302,
#    u'section_type': u'premium_recommand',
#    u'simple_item': {u'item_id': 6334560}},
#   {u'position': 303,
#    u'section_type': u'premium_recommand',
#    u'simple_item': {u'item_id': 6259971}},
#   {u'position': 304,
#    u'section_type': u'premium_recommand',
#    u'simple_item': {u'item_id': 6294478}},
#   {u'position': 305,
#    u'section_type': u'premium_recommand',
#    u'simple_item': {u'item_id': 6318900}},
#   {u'position': 306,
#    u'section_type': u'premium_recommand',
#    u'simple_item': {u'item_id': 6226840}},
#   {u'position': 307,
#    u'section_type': u'premium_recommand',
#    u'simple_item': {u'item_id': 6164534}},
#   {u'position': 308,
#    u'section_type': u'premium_recommand',
#    u'simple_item': {u'item_id': 6308655}},
#   {u'position': 309,
#    u'section_type': u'premium_recommand',
#    u'simple_item': {u'item_id': 5896370}},
#   {u'position': 310,
#    u'section_type': u'premium_recommand',
#    u'simple_item': {u'item_id': 6206325}},
#   {u'position': 311,
#    u'section_type': u'premium_recommand',
#    u'simple_item': {u'item_id': 6310529}},
#   {u'position': 312,
#    u'section_type': u'premium_recommand',
#    u'simple_item': {u'item_id': 6310698}},
#   {u'position': 313,
#    u'section_type': u'premium_recommand',
#    u'simple_item': {u'item_id': 6317811}},
#   {u'position': 314,
#    u'section_type': u'premium_recommand',
#    u'simple_item': {u'item_id': 6087107}},
#   {u'position': 315,
#    u'section_type': u'premium_recommand',
#    u'simple_item': {u'item_id': 6312909}},
#   {u'position': 316,
#    u'section_type': u'premium_recommand',
#    u'simple_item': {u'item_id': 6301127}},
#   {u'position': 317,
#    u'section_type': u'premium_recommand',
#    u'simple_item': {u'item_id': 6235437}},
#   {u'position': 318,
#    u'section_type': u'premium_recommand',
#    u'simple_item': {u'item_id': 6147920}},
#   {u'position': 319,
#    u'section_type': u'premium_recommand',
#    u'simple_item': {u'item_id': 6081681}},
#   {u'position': 320,
#    u'section_type': u'premium_recommand',
#    u'simple_item': {u'item_id': 6247090}},
#   {u'position': 321,
#    u'section_type': u'premium_recommand',
#    u'simple_item': {u'item_id': 6318194}},
#   {u'position': 322,
#    u'section_type': u'premium_recommand',
#    u'simple_item': {u'item_id': 6198198}},
#   {u'position': 323,
#    u'section_type': u'premium_recommand',
#    u'simple_item': {u'item_id': 6175339}},
#   {u'position': 324,
#    u'section_type': u'premium_recommand',
#    u'simple_item': {u'item_id': 6184055}},
#   {u'position': 325,
#    u'section_type': u'premium_recommand',
#    u'simple_item': {u'item_id': 6179561}},
#   {u'position': 326,
#    u'section_type': u'premium_recommand',
#    u'simple_item': {u'item_id': 6334520}},
#   {u'position': 327,
#    u'section_type': u'premium_recommand',
#    u'simple_item': {u'item_id': 6174625}},
#   {u'position': 328,
#    u'section_type': u'premium_recommand',
#    u'simple_item': {u'item_id': 6102301}},
#   {u'position': 329,
#    u'section_type': u'premium_recommand',
#    u'simple_item': {u'item_id': 6231326}},
#   {u'position': 330,
#    u'section_type': u'premium_recommand',
#    u'simple_item': {u'item_id': 6168232}},
#   {u'position': 331,
#    u'section_type': u'premium_recommand',
#    u'simple_item': {u'item_id': 6317777}},
#   {u'position': 332,
#    u'section_type': u'premium_recommand',
#    u'simple_item': {u'item_id': 6066118}},
#   {u'position': 333,
#    u'section_type': u'premium_recommand',
#    u'simple_item': {u'item_id': 6126628}},
#   {u'position': 334,
#    u'section_type': u'premium_recommand',
#    u'simple_item': {u'item_id': 6321609}},
#   {u'position': 335,
#    u'section_type': u'premium_recommand',
#    u'simple_item': {u'item_id': 6054176}},
#   {u'position': 336,
#    u'section_type': u'premium_recommand',
#    u'simple_item': {u'item_id': 6241745}},
#   {u'position': 337,
#    u'section_type': u'premium_recommand',
#    u'simple_item': {u'item_id': 6239675}},
#   {u'position': 338,
#    u'section_type': u'premium_recommand',
#    u'simple_item': {u'item_id': 6212309}},
#   {u'position': 339,
#    u'section_type': u'premium_recommand',
#    u'simple_item': {u'item_id': 6242082}},
#   {u'position': 340,
#    u'section_type': u'premium_recommand',
#    u'simple_item': {u'item_id': 6234040}},
#   {u'position': 341,
#    u'section_type': u'premium_recommand',
#    u'simple_item': {u'item_id': 6310297}},
#   {u'position': 342,
#    u'section_type': u'premium_recommand',
#    u'simple_item': {u'item_id': 6199357}},
#   {u'position': 343,
#    u'section_type': u'premium_recommand',
#    u'simple_item': {u'item_id': 6310589}},
#   {u'position': 344,
#    u'section_type': u'premium_recommand',
#    u'simple_item': {u'item_id': 6320226}},
#   {u'position': 345,
#    u'section_type': u'premium_recommand',
#    u'simple_item': {u'item_id': 5745336}},
#   {u'position': 346,
#    u'section_type': u'premium_recommand',
#    u'simple_item': {u'item_id': 6321317}},
#   {u'position': 347,
#    u'section_type': u'premium_recommand',
#    u'simple_item': {u'item_id': 6162883}},
#   {u'position': 348,
#    u'section_type': u'premium_recommand',
#    u'simple_item': {u'item_id': 6253900}},
#   {u'position': 349,
#    u'section_type': u'premium_recommand',
#    u'simple_item': {u'item_id': 6314971}},
#   {u'position': 350,
#    u'section_type': u'premium_recommand',
#    u'simple_item': {u'item_id': 6318733}},
#   {u'position': 351,
#    u'section_type': u'premium_recommand',
#    u'simple_item': {u'item_id': 6326659}},
#   {u'position': 352,
#    u'section_type': u'premium_recommand',
#    u'simple_item': {u'item_id': 6160842}},
#   {u'position': 353,
#    u'section_type': u'premium_recommand',
#    u'simple_item': {u'item_id': 6320551}},
#   {u'position': 354,
#    u'section_type': u'premium_recommand',
#    u'simple_item': {u'item_id': 6313618}},
#   {u'position': 355,
#    u'section_type': u'premium_recommand',
#    u'simple_item': {u'item_id': 6326304}},
#   {u'position': 356,
#    u'section_type': u'premium_recommand',
#    u'simple_item': {u'item_id': 6315136}},
#   {u'position': 357,
#    u'section_type': u'premium_recommand',
#    u'simple_item': {u'item_id': 6140007}},
#   {u'position': 358,
#    u'section_type': u'premium_recommand',
#    u'simple_item': {u'item_id': 6293355}},
#   {u'position': 359,
#    u'section_type': u'premium_recommand',
#    u'simple_item': {u'item_id': 6064335}},
#   {u'position': 360,
#    u'section_type': u'premium_recommand',
#    u'simple_item': {u'item_id': 6322230}},
#   {u'position': 361,
#    u'section_type': u'premium_recommand',
#    u'simple_item': {u'item_id': 6313497}},
#   {u'position': 362,
#    u'section_type': u'premium_recommand',
#    u'simple_item': {u'item_id': 6332025}},
#   {u'position': 363,
#    u'section_type': u'premium_recommand',
#    u'simple_item': {u'item_id': 6108640}},
#   {u'position': 364,
#    u'section_type': u'premium_recommand',
#    u'simple_item': {u'item_id': 6151742}},
#   {u'position': 365,
#    u'section_type': u'premium_recommand',
#    u'simple_item': {u'item_id': 6065489}},
#   {u'position': 366,
#    u'section_type': u'premium_recommand',
#    u'simple_item': {u'item_id': 6235342}},
#   {u'position': 367,
#    u'section_type': u'premium_recommand',
#    u'simple_item': {u'item_id': 6324915}},
#   {u'position': 368,
#    u'section_type': u'premium_recommand',
#    u'simple_item': {u'item_id': 6292287}},
#   {u'position': 369,
#    u'section_type': u'premium_recommand',
#    u'simple_item': {u'item_id': 6289860}},
#   {u'position': 370,
#    u'section_type': u'premium_recommand',
#    u'simple_item': {u'item_id': 6147827}},
#   {u'position': 371,
#    u'section_type': u'premium_recommand',
#    u'simple_item': {u'item_id': 6323305}},
#   {u'position': 372,
#    u'section_type': u'premium_recommand',
#    u'simple_item': {u'item_id': 6330774}},
#   {u'position': 373,
#    u'section_type': u'premium_recommand',
#    u'simple_item': {u'item_id': 6241692}},
#   {u'position': 374,
#    u'section_type': u'premium_recommand',
#    u'simple_item': {u'item_id': 6325949}},
#   {u'position': 375,
#    u'section_type': u'premium_recommand',
#    u'simple_item': {u'item_id': 6316634}},
#   {u'position': 376,
#    u'section_type': u'premium_recommand',
#    u'simple_item': {u'item_id': 6327870}},
#   {u'position': 377,
#    u'section_type': u'premium_recommand',
#    u'simple_item': {u'item_id': 6325457}},
#   {u'position': 378,
#    u'section_type': u'premium_recommand',
#    u'simple_item': {u'item_id': 6335704}},
#   {u'position': 379,
#    u'section_type': u'premium_recommand',
#    u'simple_item': {u'item_id': 6199373}},
#   {u'position': 380,
#    u'section_type': u'premium_recommand',
#    u'simple_item': {u'item_id': 6112063}},
#   {u'position': 381,
#    u'section_type': u'premium_recommand',
#    u'simple_item': {u'item_id': 6315704}},
#   {u'position': 382,
#    u'section_type': u'premium_recommand',
#    u'simple_item': {u'item_id': 6112938}},
#   {u'position': 383,
#    u'section_type': u'premium_recommand',
#    u'simple_item': {u'item_id': 6311607}},
#   {u'position': 384,
#    u'section_type': u'premium_recommand',
#    u'simple_item': {u'item_id': 6323200}},
#   {u'position': 385,
#    u'section_type': u'premium_recommand',
#    u'simple_item': {u'item_id': 6313762}},
#   {u'position': 386,
#    u'section_type': u'premium_recommand',
#    u'simple_item': {u'item_id': 6318656}},
#   {u'position': 387,
#    u'section_type': u'premium_recommand',
#    u'simple_item': {u'item_id': 6284740}},
#   {u'position': 388,
#    u'section_type': u'premium_recommand',
#    u'simple_item': {u'item_id': 6311570}},
#   {u'position': 389,
#    u'section_type': u'premium_recommand',
#    u'simple_item': {u'item_id': 6212292}},
#   {u'position': 390,
#    u'section_type': u'premium_recommand',
#    u'simple_item': {u'item_id': 6257498}},
#   {u'position': 391,
#    u'section_type': u'premium_recommand',
#    u'simple_item': {u'item_id': 6215641}},
#   {u'position': 392,
#    u'section_type': u'premium_recommand',
#    u'simple_item': {u'item_id': 6033516}},
#   {u'position': 393,
#    u'section_type': u'premium_recommand',
#    u'simple_item': {u'item_id': 6007453}},
#   {u'position': 394,
#    u'section_type': u'premium_recommand',
#    u'simple_item': {u'item_id': 6311721}},
#   {u'position': 395,
#    u'section_type': u'premium_recommand',
#    u'simple_item': {u'item_id': 6324770}},
#   {u'position': 396,
#    u'section_type': u'premium_recommand',
#    u'simple_item': {u'item_id': 6080490}},
#   {u'position': 397,
#    u'section_type': u'premium_recommand',
#    u'simple_item': {u'item_id': 6101298}},
#   {u'position': 398,
#    u'section_type': u'premium_recommand',
#    u'simple_item': {u'item_id': 6310337}},
#   {u'position': 399,
#    u'section_type': u'premium_recommand',
#    u'simple_item': {u'item_id': 6287930}},
#   {u'position': 400,
#    u'section_type': u'premium_recommand',
#    u'simple_item': {u'item_id': 6221558}},
#   {u'position': 401,
#    u'section_type': u'premium_recommand',
#    u'simple_item': {u'item_id': 6240373}},
#   {u'position': 402,
#    u'section_type': u'premium_recommand',
#    u'simple_item': {u'item_id': 6273789}},
#   {u'position': 403,
#    u'section_type': u'premium_recommand',
#    u'simple_item': {u'item_id': 6320276}},
#   {u'position': 404,
#    u'section_type': u'premium_recommand',
#    u'simple_item': {u'item_id': 6051027}},
#   {u'position': 405,
#    u'section_type': u'premium_recommand',
#    u'simple_item': {u'item_id': 6324996}},
#   {u'position': 406,
#    u'section_type': u'premium_recommand',
#    u'simple_item': {u'item_id': 6251162}},
#   {u'position': 407,
#    u'section_type': u'premium_recommand',
#    u'simple_item': {u'item_id': 6247778}},
#   {u'position': 408,
#    u'section_type': u'premium_recommand',
#    u'simple_item': {u'item_id': 6047876}},
#   {u'position': 409,
#    u'section_type': u'premium_recommand',
#    u'simple_item': {u'item_id': 6320556}},
#   {u'position': 410,
#    u'section_type': u'premium_recommand',
#    u'simple_item': {u'item_id': 6216362}},
#   {u'position': 411,
#    u'section_type': u'premium_recommand',
#    u'simple_item': {u'item_id': 6314702}},
#   {u'position': 412,
#    u'section_type': u'premium_recommand',
#    u'simple_item': {u'item_id': 6273992}},
#   {u'position': 413,
#    u'section_type': u'premium_recommand',
#    u'simple_item': {u'item_id': 6337255}},
#   {u'position': 414,
#    u'section_type': u'premium_recommand',
#    u'simple_item': {u'item_id': 6066056}},
#   {u'position': 415,
#    u'section_type': u'premium_recommand',
#    u'simple_item': {u'item_id': 6282720}},
#   {u'position': 416,
#    u'section_type': u'premium_recommand',
#    u'simple_item': {u'item_id': 6292512}},
#   {u'position': 417,
#    u'section_type': u'premium_recommand',
#    u'simple_item': {u'item_id': 6330319}},
#   {u'position': 418,
#    u'section_type': u'premium_recommand',
#    u'simple_item': {u'item_id': 6291098}},
#   {u'position': 419,
#    u'section_type': u'premium_recommand',
#    u'simple_item': {u'item_id': 6318889}},
#   {u'position': 420,
#    u'section_type': u'premium_recommand',
#    u'simple_item': {u'item_id': 6233360}},
#   {u'position': 421,
#    u'section_type': u'premium_recommand',
#    u'simple_item': {u'item_id': 6305720}},
#   {u'position': 422,
#    u'section_type': u'premium_recommand',
#    u'simple_item': {u'item_id': 6259103}},
#   {u'position': 423,
#    u'section_type': u'premium_recommand',
#    u'simple_item': {u'item_id': 6165892}},
#   {u'position': 424,
#    u'section_type': u'premium_recommand',
#    u'simple_item': {u'item_id': 6325302}},
#   {u'position': 425,
#    u'section_type': u'premium_recommand',
#    u'simple_item': {u'item_id': 6272740}},
#   {u'position': 426,
#    u'section_type': u'premium_recommand',
#    u'simple_item': {u'item_id': 6242334}},
#   {u'position': 427,
#    u'section_type': u'premium_recommand',
#    u'simple_item': {u'item_id': 6037238}},
#   {u'position': 428,
#    u'section_type': u'premium_recommand',
#    u'simple_item': {u'item_id': 6244778}},
#   {u'position': 429,
#    u'section_type': u'premium_recommand',
#    u'simple_item': {u'item_id': 6326720}},
#   {u'position': 430,
#    u'section_type': u'premium_recommand',
#    u'simple_item': {u'item_id': 6145639}},
#   {u'position': 431,
#    u'section_type': u'premium_recommand',
#    u'simple_item': {u'item_id': 6320896}},
#   {u'position': 432,
#    u'section_type': u'premium_recommand',
#    u'simple_item': {u'item_id': 6328487}},
#   {u'position': 433,
#    u'section_type': u'premium_recommand',
#    u'simple_item': {u'item_id': 6255753}},
#   {u'position': 434,
#    u'section_type': u'premium_recommand',
#    u'simple_item': {u'item_id': 6314486}},
#   {u'position': 435,
#    u'section_type': u'premium_recommand',
#    u'simple_item': {u'item_id': 6290524}},
#   {u'position': 436,
#    u'section_type': u'premium_recommand',
#    u'simple_item': {u'item_id': 6310099}},
#   {u'position': 437,
#    u'section_type': u'premium_recommand',
#    u'simple_item': {u'item_id': 6312239}},
#   {u'position': 438,
#    u'section_type': u'premium_recommand',
#    u'simple_item': {u'item_id': 6195670}},
#   {u'position': 439,
#    u'section_type': u'premium_recommand',
#    u'simple_item': {u'item_id': 6270320}},
#   {u'position': 440,
#    u'section_type': u'premium_recommand',
#    u'simple_item': {u'item_id': 6312787}},
#   {u'position': 441,
#    u'section_type': u'premium_recommand',
#    u'simple_item': {u'item_id': 6229619}},
#   {u'position': 442,
#    u'section_type': u'premium_recommand',
#    u'simple_item': {u'item_id': 6318387}},
#   {u'position': 443,
#    u'section_type': u'premium_recommand',
#    u'simple_item': {u'item_id': 6295250}},
#   {u'position': 444,
#    u'section_type': u'premium_recommand',
#    u'simple_item': {u'item_id': 6318753}},
#   {u'position': 445,
#    u'section_type': u'premium_recommand',
#    u'simple_item': {u'item_id': 6317326}},
#   {u'position': 446,
#    u'section_type': u'premium_recommand',
#    u'simple_item': {u'item_id': 6293982}},
#   {u'position': 447,
#    u'section_type': u'premium_recommand',
#    u'simple_item': {u'item_id': 6259499}},
#   {u'position': 448,
#    u'section_type': u'premium_recommand',
#    u'simple_item': {u'item_id': 6315878}},
#   {u'position': 449,
#    u'section_type': u'premium_recommand',
#    u'simple_item': {u'item_id': 6306071}},
#   {u'position': 450,
#    u'section_type': u'premium_recommand',
#    u'simple_item': {u'item_id': 6283840}},
#   {u'position': 451,
#    u'section_type': u'premium_recommand',
#    u'simple_item': {u'item_id': 6261999}},
#   {u'position': 452,
#    u'section_type': u'premium_recommand',
#    u'simple_item': {u'item_id': 6294685}},
#   {u'position': 453,
#    u'section_type': u'premium_recommand',
# ...
#    u'section_type': u'premium_normal',
#    u'simple_item': {u'item_id': 6158757}},
#   {u'position': 862,
#    u'section_type': u'premium_normal',
#    u'simple_item': {u'item_id': 6257405}},
#   {u'position': 863,
#    u'section_type': u'premium_normal',
#    u'simple_item': {u'item_id': 6321901}},
#   {u'position': 864,
#    u'section_type': u'premium_normal',
#    u'simple_item': {u'item_id': 6312270}},
#   {u'position': 865,
#    u'section_type': u'premium_normal',
#    u'simple_item': {u'item_id': 6113010}},
#   {u'position': 866,
#    u'section_type': u'premium_normal',
#    u'simple_item': {u'item_id': 6188300}},
#   {u'position': 867,
#    u'section_type': u'premium_normal',
#    u'simple_item': {u'item_id': 6299531}},
#   {u'position': 868,
#    u'section_type': u'premium_normal',
#    u'simple_item': {u'item_id': 6323461}},
#   {u'position': 869,
#    u'section_type': u'premium_normal',
#    u'simple_item': {u'item_id': 6118253}},
#   {u'position': 870,
#    u'section_type': u'premium_normal',
#    u'simple_item': {u'item_id': 6290553}},
#   {u'position': 871,
#    u'section_type': u'premium_normal',
#    u'simple_item': {u'item_id': 6272953}},
#   {u'position': 872,
#    u'section_type': u'premium_normal',
#    u'simple_item': {u'item_id': 6231184}},
#   {u'position': 873,
#    u'section_type': u'premium_normal',
#    u'simple_item': {u'item_id': 6237608}},
#   {u'position': 874,
#    u'section_type': u'premium_normal',
#    u'simple_item': {u'item_id': 6176055}},
#   {u'position': 875,
#    u'section_type': u'premium_normal',
#    u'simple_item': {u'item_id': 6189578}},
#   {u'position': 876,
#    u'section_type': u'premium_normal',
#    u'simple_item': {u'item_id': 6061062}},
#   {u'position': 877,
#    u'section_type': u'premium_normal',
#    u'simple_item': {u'item_id': 6213172}},
#   {u'position': 878,
#    u'section_type': u'premium_normal',
#    u'simple_item': {u'item_id': 6324005}},
#   {u'position': 879,
#    u'section_type': u'premium_normal',
#    u'simple_item': {u'item_id': 6230529}},
#   {u'position': 880,
#    u'section_type': u'premium_normal',
#    u'simple_item': {u'item_id': 6013288}},
#   {u'position': 881,
#    u'section_type': u'premium_normal',
#    u'simple_item': {u'item_id': 6184072}},
#   {u'position': 882,
#    u'section_type': u'premium_normal',
#    u'simple_item': {u'item_id': 6137677}},
#   {u'position': 883,
#    u'section_type': u'premium_normal',
#    u'simple_item': {u'item_id': 5943682}},
#   {u'position': 884,
#    u'section_type': u'premium_normal',
#    u'simple_item': {u'item_id': 6213274}},
#   {u'position': 885,
#    u'section_type': u'premium_normal',
#    u'simple_item': {u'item_id': 6099523}},
#   {u'position': 886,
#    u'section_type': u'premium_normal',
#    u'simple_item': {u'item_id': 6303719}},
#   {u'position': 887,
#    u'section_type': u'premium_normal',
#    u'simple_item': {u'item_id': 6322381}},
#   {u'position': 888,
#    u'section_type': u'premium_normal',
#    u'simple_item': {u'item_id': 6213226}},
#   {u'position': 889,
#    u'section_type': u'premium_normal',
#    u'simple_item': {u'item_id': 6206673}},
#   {u'position': 890,
#    u'section_type': u'premium_normal',
#    u'simple_item': {u'item_id': 6089393}},
#   {u'position': 891,
#    u'section_type': u'premium_normal',
#    u'simple_item': {u'item_id': 6332662}},
#   {u'position': 892,
#    u'section_type': u'premium_normal',
#    u'simple_item': {u'item_id': 6323619}},
#   {u'position': 893,
#    u'section_type': u'premium_normal',
#    u'simple_item': {u'item_id': 6266283}},
#   {u'position': 894,
#    u'section_type': u'premium_normal',
#    u'simple_item': {u'item_id': 6190359}},
#   {u'position': 895,
#    u'section_type': u'premium_normal',
#    u'simple_item': {u'item_id': 6158763}},
#   {u'position': 896,
#    u'section_type': u'premium_normal',
#    u'simple_item': {u'item_id': 6252907}},
#   {u'position': 897,
#    u'section_type': u'premium_normal',
#    u'simple_item': {u'item_id': 6206906}},
#   {u'position': 898,
#    u'section_type': u'premium_normal',
#    u'simple_item': {u'item_id': 6264670}},
#   {u'position': 899,
#    u'section_type': u'premium_normal',
#    u'simple_item': {u'item_id': 6297925}},
#   {u'position': 900,
#    u'section_type': u'premium_normal',
#    u'simple_item': {u'item_id': 6197303}},
#   {u'position': 901,
#    u'section_type': u'premium_normal',
#    u'simple_item': {u'item_id': 6156206}},
#   {u'position': 902,
#    u'section_type': u'premium_normal',
#    u'simple_item': {u'item_id': 6172562}},
#   {u'position': 903,
#    u'section_type': u'premium_normal',
#    u'simple_item': {u'item_id': 6330923}},
#   {u'position': 904,
#    u'section_type': u'premium_normal',
#    u'simple_item': {u'item_id': 6232385}},
#   {u'position': 905,
#    u'section_type': u'premium_normal',
#    u'simple_item': {u'item_id': 6330577}},
#   {u'position': 906,
#    u'section_type': u'premium_normal',
#    u'simple_item': {u'item_id': 6295166}},
#   {u'position': 907,
#    u'section_type': u'premium_normal',
#    u'simple_item': {u'item_id': 6202105}},
#   {u'position': 908,
#    u'section_type': u'premium_normal',
#    u'simple_item': {u'item_id': 6104579}},
#   {u'position': 909,
#    u'section_type': u'premium_normal',
#    u'simple_item': {u'item_id': 6231240}},
#   {u'position': 910,
#    u'section_type': u'premium_normal',
#    u'simple_item': {u'item_id': 5920605}},
#   {u'position': 911,
#    u'section_type': u'premium_normal',
#    u'simple_item': {u'item_id': 6106533}},
#   {u'position': 912,
#    u'section_type': u'premium_normal',
#    u'simple_item': {u'item_id': 6151650}},
#   {u'position': 913,
#    u'section_type': u'premium_normal',
#    u'simple_item': {u'item_id': 6228758}},
#   {u'position': 914,
#    u'section_type': u'premium_normal',
#    u'simple_item': {u'item_id': 6172381}},
#   {u'position': 915,
#    u'section_type': u'premium_normal',
#    u'simple_item': {u'item_id': 6250843}},
#   {u'position': 916,
#    u'section_type': u'premium_normal',
#    u'simple_item': {u'item_id': 6140543}},
#   {u'position': 917,
#    u'section_type': u'premium_normal',
#    u'simple_item': {u'item_id': 6308189}},
#   {u'position': 918,
#    u'section_type': u'premium_normal',
#    u'simple_item': {u'item_id': 6260118}},
#   {u'position': 919,
#    u'section_type': u'premium_normal',
#    u'simple_item': {u'item_id': 5970244}},
#   {u'position': 920,
#    u'section_type': u'premium_normal',
#    u'simple_item': {u'item_id': 6090324}},
#   {u'position': 921,
#    u'section_type': u'premium_normal',
#    u'simple_item': {u'item_id': 6143983}},
#   {u'position': 922,
#    u'section_type': u'premium_normal',
#    u'simple_item': {u'item_id': 6128919}},
#   {u'position': 923,
#    u'section_type': u'premium_normal',
#    u'simple_item': {u'item_id': 6220819}},
#   {u'position': 924,
#    u'section_type': u'premium_normal',
#    u'simple_item': {u'item_id': 6086594}},
#   {u'position': 925,
#    u'section_type': u'premium_normal',
#    u'simple_item': {u'item_id': 6055460}},
#   {u'position': 926,
#    u'section_type': u'premium_normal',
#    u'simple_item': {u'item_id': 6168140}},
#   {u'position': 927,
#    u'section_type': u'premium_normal',
#    u'simple_item': {u'item_id': 6308052}},
#   {u'position': 928,
#    u'section_type': u'premium_normal',
#    u'simple_item': {u'item_id': 6091922}},
#   {u'position': 929,
#    u'section_type': u'premium_normal',
#    u'simple_item': {u'item_id': 6210233}},
#   {u'position': 930,
#    u'section_type': u'premium_normal',
#    u'simple_item': {u'item_id': 6313727}},
#   {u'position': 931,
#    u'section_type': u'premium_normal',
#    u'simple_item': {u'item_id': 6264456}},
#   {u'position': 932,
#    u'section_type': u'premium_normal',
#    u'simple_item': {u'item_id': 6297880}},
#   {u'position': 933,
#    u'section_type': u'premium_normal',
#    u'simple_item': {u'item_id': 6092391}},
#   {u'position': 934,
#    u'section_type': u'premium_normal',
#    u'simple_item': {u'item_id': 6293711}},
#   {u'position': 935,
#    u'section_type': u'premium_normal',
#    u'simple_item': {u'item_id': 6221513}},
#   {u'position': 936,
#    u'section_type': u'premium_normal',
#    u'simple_item': {u'item_id': 6315558}},
#   {u'position': 937,
#    u'section_type': u'premium_normal',
#    u'simple_item': {u'item_id': 6086047}},
#   {u'position': 938,
#    u'section_type': u'premium_normal',
#    u'simple_item': {u'item_id': 6224565}},
#   {u'position': 939,
#    u'section_type': u'premium_normal',
#    u'simple_item': {u'item_id': 5676307}},
#   {u'position': 940,
#    u'section_type': u'premium_normal',
#    u'simple_item': {u'item_id': 5882204}},
#   {u'position': 941,
#    u'section_type': u'premium_normal',
#    u'simple_item': {u'item_id': 6245057}},
#   {u'position': 942,
#    u'section_type': u'premium_normal',
#    u'simple_item': {u'item_id': 6172485}},
#   {u'position': 943,
#    u'section_type': u'premium_normal',
#    u'simple_item': {u'item_id': 6242763}},
#   {u'position': 944,
#    u'section_type': u'premium_normal',
#    u'simple_item': {u'item_id': 5873631}},
#   {u'position': 945,
#    u'section_type': u'premium_normal',
#    u'simple_item': {u'item_id': 6153431}},
#   {u'position': 946,
#    u'section_type': u'premium_normal',
#    u'simple_item': {u'item_id': 6193173}},
#   {u'position': 947,
#    u'section_type': u'premium_normal',
#    u'simple_item': {u'item_id': 5510841}},
#   {u'position': 948,
#    u'section_type': u'premium_normal',
#    u'simple_item': {u'item_id': 5783144}},
#   {u'position': 949,
#    u'section_type': u'premium_normal',
#    u'simple_item': {u'item_id': 6244709}},
#   {u'position': 950,
#    u'section_type': u'premium_normal',
#    u'simple_item': {u'item_id': 6129257}},
#   {u'position': 951,
#    u'section_type': u'premium_normal',
#    u'simple_item': {u'item_id': 6277246}},
#   {u'position': 952,
#    u'section_type': u'premium_normal',
#    u'simple_item': {u'item_id': 6175937}},
#   {u'position': 953,
#    u'section_type': u'premium_normal',
#    u'simple_item': {u'item_id': 6159943}},
#   {u'position': 954,
#    u'section_type': u'premium_normal',
#    u'simple_item': {u'item_id': 6333610}},
#   {u'position': 955,
#    u'section_type': u'premium_normal',
#    u'simple_item': {u'item_id': 6321578}},
#   {u'position': 956,
#    u'section_type': u'premium_normal',
#    u'simple_item': {u'item_id': 6308036}},
#   {u'position': 957,
#    u'section_type': u'premium_normal',
#    u'simple_item': {u'item_id': 6130316}},
#   {u'position': 958,
#    u'section_type': u'premium_normal',
#    u'simple_item': {u'item_id': 6271330}},
#   {u'position': 959,
#    u'section_type': u'premium_normal',
#    u'simple_item': {u'item_id': 6241155}},
#   {u'position': 960,
#    u'section_type': u'premium_normal',
#    u'simple_item': {u'item_id': 6194947}},
#   {u'position': 961,
#    u'section_type': u'premium_normal',
#    u'simple_item': {u'item_id': 6120505}},
#   {u'position': 962,
#    u'section_type': u'premium_normal',
#    u'simple_item': {u'item_id': 5653005}},
#   {u'position': 963,
#    u'section_type': u'premium_normal',
#    u'simple_item': {u'item_id': 6220193}},
#   {u'position': 964,
#    u'section_type': u'premium_normal',
#    u'simple_item': {u'item_id': 6110176}},
#   {u'position': 965,
#    u'section_type': u'premium_normal',
#    u'simple_item': {u'item_id': 6233405}},
#   {u'position': 966,
#    u'section_type': u'premium_normal',
#    u'simple_item': {u'item_id': 6335281}},
#   {u'position': 967,
#    u'section_type': u'premium_normal',
#    u'simple_item': {u'item_id': 6214052}},
#   {u'position': 968,
#    u'section_type': u'premium_normal',
#    u'simple_item': {u'item_id': 6301049}},
#   {u'position': 969,
#    u'section_type': u'premium_normal',
#    u'simple_item': {u'item_id': 6232373}},
#   {u'position': 970,
#    u'section_type': u'premium_normal',
#    u'simple_item': {u'item_id': 6254477}},
#   {u'position': 971,
#    u'section_type': u'premium_normal',
#    u'simple_item': {u'item_id': 6175436}},
#   {u'position': 972,
#    u'section_type': u'premium_normal',
#    u'simple_item': {u'item_id': 6115075}},
#   {u'position': 973,
#    u'section_type': u'premium_normal',
#    u'simple_item': {u'item_id': 6217777}},
#   {u'position': 974,
#    u'section_type': u'premium_normal',
#    u'simple_item': {u'item_id': 6236710}},
#   {u'position': 975,
#    u'section_type': u'premium_normal',
#    u'simple_item': {u'item_id': 6265371}},
#   {u'position': 976,
#    u'section_type': u'premium_normal',
#    u'simple_item': {u'item_id': 6251452}},
#   {u'position': 977,
#    u'section_type': u'premium_normal',
#    u'simple_item': {u'item_id': 6328203}},
#   {u'position': 978,
#    u'section_type': u'premium_normal',
#    u'simple_item': {u'item_id': 6106142}},
#   {u'position': 979,
#    u'section_type': u'premium_normal',
#    u'simple_item': {u'item_id': 6106276}},
#   {u'position': 980,
#    u'section_type': u'premium_normal',
#    u'simple_item': {u'item_id': 6331220}},
#   {u'position': 981,
#    u'section_type': u'premium_normal',
#    u'simple_item': {u'item_id': 6243538}},
#   {u'position': 982,
#    u'section_type': u'premium_normal',
#    u'simple_item': {u'item_id': 6110455}},
#   {u'position': 983,
#    u'section_type': u'premium_normal',
#    u'simple_item': {u'item_id': 6334663}},
#   {u'position': 984,
#    u'section_type': u'premium_normal',
#    u'simple_item': {u'item_id': 6317156}},
#   {u'position': 985,
#    u'section_type': u'premium_normal',
#    u'simple_item': {u'item_id': 6301836}},
#   {u'position': 986,
#    u'section_type': u'premium_normal',
#    u'simple_item': {u'item_id': 6158832}},
#   {u'position': 987,
#    u'section_type': u'premium_normal',
#    u'simple_item': {u'item_id': 6020410}},
#   {u'position': 988,
#    u'section_type': u'premium_normal',
#    u'simple_item': {u'item_id': 6243244}},
#   {u'position': 989,
#    u'section_type': u'premium_normal',
#    u'simple_item': {u'item_id': 6299976}},
#   {u'position': 990,
#    u'section_type': u'premium_normal',
#    u'simple_item': {u'item_id': 6078870}},
#   {u'position': 991,
#    u'section_type': u'premium_normal',
#    u'simple_item': {u'item_id': 6253112}},
#   {u'position': 992,
#    u'section_type': u'premium_normal',
#    u'simple_item': {u'item_id': 6330149}},
#   {u'position': 993,
#    u'section_type': u'premium_normal',
#    u'simple_item': {u'item_id': 6163254}},
#   {u'position': 994,
#    u'section_type': u'premium_normal',
#    u'simple_item': {u'item_id': 6190324}},
#   {u'position': 995,
#    u'section_type': u'premium_normal',
#    u'simple_item': {u'item_id': 6064301}},
#   {u'position': 996,
#    u'section_type': u'premium_normal',
#    u'simple_item': {u'item_id': 6234000}},
#   {u'position': 997,
#    u'section_type': u'premium_normal',
#    u'simple_item': {u'item_id': 6245012}},
#   {u'position': 998,
#    u'section_type': u'premium_normal',
#    u'simple_item': {u'item_id': 6062753}},
#   {u'position': 999,
#    u'section_type': u'premium_normal',
#    u'simple_item': {u'item_id': 6080233}},
#   ...],
#  u'sections': [{u'event_button_icon': u'http://s.zigbang.com/v2/ic_question20dp.png',
#    u'section_bg_color': u'#008fbf',
#    u'section_icon': u'http://s.zigbang.com/v2/ic_ansim.png',
#    u'section_item_count': 0,
#    u'section_title': u'\uc774 \uc9c0\uc5ed <b>VIP \ubc29</b>',
#    u'section_title_color': u'#ffffff',
#    u'section_type': u'vip'},
#   {u'event_button_icon': u'http://s.zigbang.com/v2/ic_question20dp.png',
#    u'section_bg_color': u'#0ec4bf',
#    u'section_icon': u'http://s.zigbang.com/v2/ic_ansim.png',
#    u'section_item_count': 594,
#    u'section_title': u'\uc774 \uc9c0\uc5ed <b>\ucd94\ucc9c \ubc29</b>',
#    u'section_title_color': u'#ffffff',
#    u'section_type': u'premium_recommand'},
#   {u'event_button_icon': u'http://s.zigbang.com/v2/ic_question20dp.png',
#    u'section_bg_color': u'#00ad69',
#    u'section_icon': u'http://s.zigbang.com/v2/ic_ansim.png',
#    u'section_item_count': 2444,
#    u'section_title': u'\uc774 \uc9c0\uc5ed <b>\uc77c\ubc18 \ubc29</b>',
#    u'section_title_color': u'#ffffff',
#    u'section_type': u'premium_normal'},
#   {u'event_button_icon': None,
#    u'section_bg_color': u'#4a4f55',
#    u'section_icon': u'http://s.zigbang.com/v2/ic_location18dp.png',
#    u'section_item_count': 5,
#    u'section_title': u'\uc774 \uc9c0\uc5ed <b>\ucd5c\uc2e0 \ubc29</b>',
#    u'section_title_color': u'#ffffff',
#    u'section_type': u'recommand'},
#   {u'event_button_icon': None,
#    u'section_bg_color': u'#ada29a',
#    u'section_icon': u'http://s.zigbang.com/v2/ic_location18dp.png',
#    u'section_item_count': 52,
#    u'section_title': u'\uc774 \uc9c0\uc5ed <b>\uc77c\ubc18 \ubc29</b>',
#    u'section_title_color': u'#ffffff',
#    u'section_type': u'normal'}],
#  u'total_count': 3095}

# %%
zbdatalist
# Out:
# <html><body><p>{"list_items":[{"simple_item":{"item_id":6257496},"section_type":"premium_recommand","position":0},{"simple_item":{"item_id":6265892},"section_type":"premium_recommand","position":1},{"simple_item":{"item_id":6166604},"section_type":"premium_recommand","position":2},{"simple_item":{"item_id":6295405},"section_type":"premium_recommand","position":3},{"simple_item":{"item_id":6245604},"section_type":"premium_recommand","position":4},{"simple_item":{"item_id":6277188},"section_type":"premium_recommand","position":5},{"simple_item":{"item_id":6122565},"section_type":"premium_recommand","position":6},{"simple_item":{"item_id":6320896},"section_type":"premium_recommand","position":7},{"simple_item":{"item_id":6327855},"section_type":"premium_recommand","position":8},{"simple_item":{"item_id":6314971},"section_type":"premium_recommand","position":9},{"simple_item":{"item_id":6334520},"section_type":"premium_recommand","position":10},{"simple_item":{"item_id":6272571},"section_type":"premium_recommand","position":11},{"simple_item":{"item_id":6317361},"section_type":"premium_recommand","position":12},{"simple_item":{"item_id":6243208},"section_type":"premium_recommand","position":13},{"simple_item":{"item_id":6233360},"section_type":"premium_recommand","position":14},{"simple_item":{"item_id":6198198},"section_type":"premium_recommand","position":15},{"simple_item":{"item_id":6327980},"section_type":"premium_recommand","position":16},{"simple_item":{"item_id":6229619},"section_type":"premium_recommand","position":17},{"simple_item":{"item_id":6116714},"section_type":"premium_recommand","position":18},{"simple_item":{"item_id":6126628},"section_type":"premium_recommand","position":19},{"simple_item":{"item_id":6308225},"section_type":"premium_recommand","position":20},{"simple_item":{"item_id":6284604},"section_type":"premium_recommand","position":21},{"simple_item":{"item_id":6200301},"section_type":"premium_recommand","position":22},{"simple_item":{"item_id":6259971},"section_type":"premium_recommand","position":23},{"simple_item":{"item_id":6131041},"section_type":"premium_recommand","position":24},{"simple_item":{"item_id":6150424},"section_type":"premium_recommand","position":25},{"simple_item":{"item_id":6293355},"section_type":"premium_recommand","position":26},{"simple_item":{"item_id":6287659},"section_type":"premium_recommand","position":27},{"simple_item":{"item_id":6330319},"section_type":"premium_recommand","position":28},{"simple_item":{"item_id":6312834},"section_type":"premium_recommand","position":29},{"simple_item":{"item_id":6183741},"section_type":"premium_recommand","position":30},{"simple_item":{"item_id":6324854},"section_type":"premium_recommand","position":31},{"simple_item":{"item_id":6235342},"section_type":"premium_recommand","position":32},{"simple_item":{"item_id":6264640},"section_type":"premium_recommand","position":33},{"simple_item":{"item_id":6251086},"section_type":"premium_recommand","position":34},{"simple_item":{"item_id":6305253},"section_type":"premium_recommand","position":35},{"simple_item":{"item_id":6318609},"section_type":"premium_recommand","position":36},{"simple_item":{"item_id":6335703},"section_type":"premium_recommand","position":37},{"simple_item":{"item_id":6290506},"section_type":"premium_recommand","position":38},{"simple_item":{"item_id":6335831},"section_type":"premium_recommand","position":39},{"simple_item":{"item_id":6139641},"section_type":"premium_recommand","position":40},{"simple_item":{"item_id":6278836},"section_type":"premium_recommand","position":41},{"simple_item":{"item_id":6316244},"section_type":"premium_recommand","position":42},{"simple_item":{"item_id":6231157},"section_type":"premium_recommand","position":43},{"simple_item":{"item_id":6222529},"section_type":"premium_recommand","position":44},{"simple_item":{"item_id":6172290},"section_type":"premium_recommand","position":45},{"simple_item":{"item_id":6321923},"section_type":"premium_recommand", ...

# %%
pd.DataFrame(json_zb['list_items'])
# Out:
#       position       section_type            simple_item
# 0            0  premium_recommand  {u'item_id': 6243828}
# 1            1  premium_recommand  {u'item_id': 6092255}
# 2            2  premium_recommand  {u'item_id': 6234041}
# 3            3  premium_recommand  {u'item_id': 6131076}
# 4            4  premium_recommand  {u'item_id': 6247948}
# 5            5  premium_recommand  {u'item_id': 6095930}
# 6            6  premium_recommand  {u'item_id': 6335700}
# 7            7  premium_recommand  {u'item_id': 6288279}
# 8            8  premium_recommand  {u'item_id': 6307000}
# 9            9  premium_recommand  {u'item_id': 6310347}
# 10          10  premium_recommand  {u'item_id': 6297817}
# 11          11  premium_recommand  {u'item_id': 6321776}
# 12          12  premium_recommand  {u'item_id': 6117373}
# 13          13  premium_recommand  {u'item_id': 6198915}
# 14          14  premium_recommand  {u'item_id': 6311600}
# 15          15  premium_recommand  {u'item_id': 6317695}
# 16          16  premium_recommand  {u'item_id': 6321082}
# 17          17  premium_recommand  {u'item_id': 6279777}
# 18          18  premium_recommand  {u'item_id': 6308314}
# 19          19  premium_recommand  {u'item_id': 6186174}
# 20          20  premium_recommand  {u'item_id': 6315400}
# 21          21  premium_recommand  {u'item_id': 6297924}
# 22          22  premium_recommand  {u'item_id': 6333067}
# 23          23  premium_recommand  {u'item_id': 6322273}
# 24          24  premium_recommand  {u'item_id': 6292964}
# 25          25  premium_recommand  {u'item_id': 6264607}
# 26          26  premium_recommand  {u'item_id': 6309715}
# 27          27  premium_recommand  {u'item_id': 6314314}
# 28          28  premium_recommand  {u'item_id': 6278836}
# 29          29  premium_recommand  {u'item_id': 6317582}
# ...        ...                ...                    ...
# 3065      3065             normal  {u'item_id': 6324059}
# 3066      3066             normal  {u'item_id': 6314487}
# 3067      3067             normal  {u'item_id': 6329145}
# 3068      3068             normal  {u'item_id': 6119229}
# 3069      3069             normal  {u'item_id': 6009229}
# 3070      3070             normal  {u'item_id': 6086523}
# 3071      3071             normal  {u'item_id': 6308322}
# 3072      3072             normal  {u'item_id': 6285657}
# 3073      3073             normal  {u'item_id': 6075022}
# 3074      3074             normal  {u'item_id': 6300595}
# 3075      3075             normal  {u'item_id': 6183778}
# 3076      3076             normal  {u'item_id': 6205316}
# 3077      3077             normal  {u'item_id': 6309369}
# 3078      3078             normal  {u'item_id': 6307618}
# 3079      3079             normal  {u'item_id': 6325909}
# 3080      3080             normal  {u'item_id': 6155171}
# 3081      3081             normal  {u'item_id': 6289618}
# 3082      3082             normal  {u'item_id': 6319707}
# 3083      3083             normal  {u'item_id': 6168606}
# 3084      3084             normal  {u'item_id': 6077719}
# 3085      3085             normal  {u'item_id': 6326910}
# 3086      3086             normal  {u'item_id': 6108218}
# 3087      3087             normal  {u'item_id': 6068958}
# 3088      3088             normal  {u'item_id': 6164798}
# 3089      3089             normal  {u'item_id': 6161974}
# 3090      3090             normal  {u'item_id': 6319712}
# 3091      3091             normal  {u'item_id': 6289192}
# 3092      3092             normal  {u'item_id': 6307761}
# 3093      3093             normal  {u'item_id': 6325537}
# 3094      3094             normal  {u'item_id': 6094089}
#
# [3095 rows x 3 columns]

# %%
df = pd.DataFrame(json_zb['list_items'])
pd.DataFrame(df.simple_item[3:15:2])
# Out:
#               simple_item
# 3   {u'item_id': 6131076}
# 5   {u'item_id': 6095930}
# 7   {u'item_id': 6288279}
# 9   {u'item_id': 6310347}
# 11  {u'item_id': 6321776}
# 13  {u'item_id': 6198915}

# %% [markdown]
# df.item[3:15] ?
# * Slicing
#     * 숫자 Index 를 가지는 경우 일부만 잘라 이용할 수 있음

# %%
import xml.etree.ElementTree as et
import requests
import pandas as pd

weather_rss_url = 'http://www.kma.go.kr/wid/queryDFSRSS.jsp?zone=1159068000'
response = requests.get(weather_rss_url)
root = et.fromstring(response.content)
root_data = root.find('channel').find('item').find('description').find('body')
li_data = root_data.findall('data')

# column name 을 얻기 위해 첫번째 data 의 tag만 list로 추출
f_data = li_data[0]
items = f_data.iter()
list_col_name = []
for item in items.next():
    list_col_name.append(item.tag)
print list_col_name

# tag list 를 column name 으로 하는 dataframe 생성
df = pd.DataFrame(columns=list_col_name)

# data 를 돌면서 row 를 추가
for data in li_data:
    row = {} # row 로 추가될 값을 dictionary 로 추출
    items = data.iter()
    for item in items.next():
        row[item.tag]=item.text # {item.tag:item.text}
    s = pd.Series(row, name=data.attrib['seq'])
    df = df.append(s)
# df = df.convert_objects(convert_numeric=True) 
df
# Out:
# ['hour', 'day', 'temp', 'tmx', 'tmn', 'sky', 'pty', 'wfKor', 'wfEn', 'pop', 'r12', 's12', 'ws', 'wd', 'wdKor', 'wdEn', 'reh', 'r06', 's06']
#    hour day  temp   tmx     tmn sky pty  wfKor           wfEn pop  r12  s12  \
# 0     9   0   8.7   9.5  -999.0   4   1      비           Rain  61  0.0  0.0
# 1    12   0   8.8   9.5  -999.0   4   0     흐림         Cloudy  30  0.0  0.0
# 2    15   0   8.6   9.5  -999.0   4   0     흐림         Cloudy  30  0.0  0.0
# 3    18   0   7.7   9.5  -999.0   3   0  구름 많음  Mostly Cloudy  20  0.0  0.0
# 4    21   0   5.4   9.5  -999.0   2   0  구름 조금  Partly Cloudy  10  0.0  0.0
# 5    24   0   3.0   9.5  -999.0   2   0  구름 조금  Partly Cloudy  10  0.0  0.0
# 6     3   1   0.2   8.2    -1.8   1   0     맑음          Clear   0  0.0  0.0
# 7     6   1  -0.9   8.2    -1.8   1   0     맑음          Clear   0  0.0  0.0
# 8     9   1   1.5   8.2    -1.8   1   0     맑음          Clear   0  0.0  0.0
# 9    12   1   5.6   8.2    -1.8   1   0     맑음          Clear   0  0.0  0.0
# 10   15   1   7.6   8.2    -1.8   1   0     맑음          Clear   0  0.0  0.0
# 11   18   1   5.6   8.2    -1.8   1   0     맑음          Clear   0  0.0  0.0
# 12   21   1   3.6   8.2    -1.8   1   0     맑음          Clear   0  0.0  0.0
# 13   24   1   2.2   8.2    -1.8   1   0     맑음          Clear   0  0.0  0.0
# 14    3   2   1.2  10.6    -0.5   1   0     맑음          Clear   0  0.0  0.0
# 15    6   2   0.3  10.6    -0.5   1   0     맑음          Clear   0  0.0  0.0
# 16    9   2   3.7  10.6    -0.5   1   0     맑음          Clear   0  0.0  0.0
# 17   12   2   8.1  10.6    -0.5   1   0     맑음          Clear   0  0.0  0.0
# 18   15   2  10.1  10.6    -0.5   2   0  구름 조금  Partly Cloudy  10  0.0  0.0
# 19   18   2   8.1  10.6    -0.5   2   0  구름 조금  Partly Cloudy  10  0.0  0.0
# 20   21   2   6.6  10.6    -0.5   3   0  구름 많음  Mostly Cloudy  20  0.0  0.0
# 21   24   2   7.1  10.6    -0.5   3   0  구름 많음  Mostly Cloudy  20  0.0  0.0
#
#                     ws wd wdKor wdEn reh        r06  s06
# 0                  1.0  4     남    S  75  2.0120292  0.0
# 1                  3.2  7    북서   NW  65  2.0120292  0.0
# 2   3.8000000000000003  7    북서   NW  52        0.0  0.0
# 3                  4.0  7    북서   NW  47        0.0  0.0
# 4    4.800000000000001  7    북서   NW  48        0.0  0.0
# 5                  5.2  7    북서   NW  47        0.0  0.0
# 6                  5.0  7    북서   NW  46        0.0  0.0
# 7                  4.4  7    북서   NW  49        0.0  0.0
# 8                  4.0  7    북서   NW  42        0.0  0.0
# 9                  4.0  7    북서   NW  33        0.0  0.0
# 10                 4.0  7    북서   NW  28        0.0  0.0
# 11                 3.0  7    북서   NW  37        0.0  0.0
# 12                 2.6  7    북서   NW  44        0.0  0.0
# 13  1.9000000000000001  7    북서   NW  53        0.0  0.0
# 14  0.6000000000000001  1    북동   NE  63        0.0  0.0
# 15                 0.8  3    남동   SE  64        0.0  0.0
# 16                 1.0  2     동    E  44        0.0  0.0
# 17                 2.1  1    북동   NE  31        0.0  0.0
# 18                 1.3  3    남동   SE  34        0.0  0.0
# 19                 1.1  3    남동   SE  51        0.0  0.0
# 20                 1.5  3    남동   SE  58        0.0  0.0
# 21                 1.3  3    남동   SE  62        0.0  0.0

# %%
import bs4 as soup
import requests
response = requests.get('http://naver.com')
response
response.text
root = soup.BeautifulSoup(response.text)
with codecs.open('newsjelly_obesity_BMI.csv','r','cp949') as file:
    for line in file.readlines():
        print line
# Out:
# 체질량지수(BMI)가 25이상의 비율,,,,
#
# ,2009,2010,2011,2012
#
# 서울시,21.4,21.7,22.7,23.7
#
# 강남구,18.6,16.3,16.1,19.2
#
# 강동구,21.7,21.1,23.7,23.8
#
# 강북구,23.4,22.1,25.3,23.8
#
# 강서구,20.7,21.2,23.9,24.5
#
# 관악구,22.2,20.5,24.1,23.2
#
# 광진구,20.2,21,20.6,21.3
#
# 구로구,25.4,21.3,24.8,22.2
#
# 금천구,23.5,22.4,21.6,25.7
#
# 노원구,20.2,25.1,21,25.3
#
# 도봉구,21.5,26.6,24.7,25.1
#
# 동대문구,20,22.7,26.3,27.4
#
# 동작구,20.9,24.7,22.5,23.7
#
# 마포구,19.9,23,18.5,23.3
#
# 서대문구,19.5,22.6,25.6,25.7
#
# 서초구,22.5,19.4,20.9,20.9
#
# 성동구,22.7,21.6,22.1,21.7
#
# 성북구,22.5,23.2,23.6,26.6
#
# 송파구,19.9,17.9,22.7,24.6
#
# 양천구,25.4,19.4,23.1,24.3
#
# 영등포구,19.2,22.6,22.6,22.3
#
# 용산구,19.5,17.7,22.6,27.7
#
# 은평구,23.5,23.8,23.5,21.4
#
# 종로구,21.1,22.7,22,22.7
#
# 중구,23.5,19.7,20.1,20.9
#
# 중랑구,18.2,26.6,26.5,24.9

# %% [markdown]
# ##CSV (Comma-Seperated Values)
# * 쉼표(,)로 구분된 텍스트 데이터
# * 유사품
#     * TSV (Tab-Seperated Values)
#     * SSV (Space-Seperated Values)

# %% [markdown]
# ###Using csv library

# %%
import csv

# %%
file = open('coffees.csv','r')

# %% [markdown]
# open('파일이름', '모드')
# 모드
# * r - read
# * w - write
# * a - append

# %%
reader = csv.reader(file, delimiter=',', quotechar='"')

# %%
for row in reader:
    print row
# Out:
# ['mericano', 'caffe latte', 'dutch coffee', 'espresso', 'cappuccino']
# ['europicano', 'greentea latte', 'england coffee', 'nesopresso', 'italiano']

# %%
file.close()

# %%
file = open('coffees_using_csv.csv', 'w')

# %%
writer = csv.writer(file, delimiter=',', quotechar='"', quoting=csv.QUOTE_MINIMAL)

# %%
writer.writerow(['americano', 'caffe latte', 'dutch, coffee', 'espresso', 'cappuccino'])

# %%
writer.writerow(['europicano', 'greentea latte', 'england coffee', 'nesopresso', 'italiano'])

# %%
file.close()

# %% [markdown]
# ###Using pandas

# %%
import pandas as pd

# %%
df = pd.read_csv('coffees.csv', names=['a','b','c','d','e','f'])

# %%
df
# Out:
#             a               b               c           d           e   f
# 0    mericano     caffe latte    dutch coffee    espresso  cappuccino NaN
# 1  europicano  greentea latte  england coffee  nesopresso    italiano NaN

# %%
df.to_csv('/Users/luinhon/Downloads/coffees_using_pandas.csv')

# %% [markdown]
# ##JSON (Javascript Object Notation)
# * 텍스트 포멧으로 저장하여 이용하기도 함

# %% [markdown]
# ###Using json library

# %%
import json

# %%
file = open('donuts.json', 'r')

# %%
decoded = json.load(file)

# %%
decoded
# Out:
# {u'batters': {u'batter': [{u'id': u'1001', u'type': u'Regular'},
#    {u'id': u'1002', u'type': u'Chocolate'},
#    {u'id': u'1003', u'type': u'Blueberry'},
#    {u'id': u'1004', u'type': u"Devil's Food"}]},
#  u'id': u'0001',
#  u'name': u'Cake',
#  u'ppu': 0.55,
#  u'topping': [{u'id': u'5001', u'type': u'None'},
#   {u'id': u'5002', u'type': u'Glazed'},
#   {u'id': u'5005', u'type': u'Sugar'},
#   {u'id': u'5007', u'type': u'Powdered Sugar'},
#   {u'id': u'5006', u'type': u'Chocolate with Sprinkles'},
#   {u'id': u'5003', u'type': u'Chocolate'},
#   {u'id': u'5004', u'type': u'Maple'}],
#  u'type': u'donut'}

# %%
print decoded['type']
# Out:
# donut

# %%
print decoded['name']
# Out:
# Cake

# %%
decoded['batters']
# Out:
# {u'batter': [{u'id': u'1001', u'type': u'Regular'},
#   {u'id': u'1002', u'type': u'Chocolate'},
#   {u'id': u'1003', u'type': u'Blueberry'},
#   {u'id': u'1004', u'type': u"Devil's Food"}]}

# %%
decoded['topping']
# Out:
# [{u'id': u'5001', u'type': u'None'},
#  {u'id': u'5002', u'type': u'Glazed'},
#  {u'id': u'5005', u'type': u'Sugar'},
#  {u'id': u'5007', u'type': u'Powdered Sugar'},
#  {u'id': u'5006', u'type': u'Chocolate with Sprinkles'},
#  {u'id': u'5003', u'type': u'Chocolate'},
#  {u'id': u'5004', u'type': u'Maple'}]

# %%
file.close()

# %%
file = open('donut_using_json.json', 'w')

# %%
england_league_income = 9995
england_teams = ['liverpool','arsenal','manchester']
spain_league_income = 12985
spain_teams = ['barcelona','madrid','atlantico']
italy_league_income = 7128
italy_teams = ['juventus','ac milan','forgot']

soccer_dic = { 'leagues': [
        {'country': 'england', 'income': england_league_income, 'teams': england_teams},
        {'country': 'spain', 'income': spain_league_income, 'teams': spain_teams },
        {'country': 'italy', 'income': italy_league_income, 'teams': italy_teams },
    ]}

soccer_dic
# Out:
# {'leagues': [{'country': 'england',
#    'income': 9995,
#    'teams': ['liverpool', 'arsenal', 'manchester']},
#   {'country': 'spain',
#    'income': 12985,
#    'teams': ['barcelona', 'madrid', 'atlantico']},
#   {'country': 'italy',
#    'income': 7128,
#    'teams': ['juventus', 'ac milan', 'forgot']}]}

# %%
file.write(json.dumps(soccer_dic))

# %%
file.close()

# %% [markdown]
# ###Using pandas

# %%
import pandas as pd

# %%
pd.read_json('donuts.json')
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-71-7c4d28a665a3> in <module>()
# ----> 1 pd.read_json('donuts.json')
#
# /Users/luinhon/anaconda/lib/python2.7/site-packages/pandas/io/json.pyc in read_json(path_or_buf, orient, typ, dtype, convert_axes, convert_dates, keep_default_dates, numpy, precise_float, date_unit)
#     209         obj = FrameParser(json, orient, dtype, convert_axes, convert_dates,
#     210                           keep_default_dates, numpy, precise_float,
# --> 211                           date_unit).parse()
#     212
#     213     if typ == 'series' or obj is None:
#
# /Users/luinhon/anaconda/lib/python2.7/site-packages/pandas/io/json.pyc in parse(self)
#     277
#     278         else:
# --> 279             self._parse_no_numpy()
#     280
#     281         if self.obj is None:
#
# /Users/luinhon/anaconda/lib/python2.7/site-packages/pandas/io/json.pyc in _parse_no_numpy(self)
#     494         if orient == "columns":
#     495             self.obj = DataFrame(
# --> 496                 loads(json, precise_float=self.precise_float), dtype=None)
#     497         elif orient == "split":
#     498             decoded = dict((str(k), v)
#
# /Users/luinhon/anaconda/lib/python2.7/site-packages/pandas/core/frame.pyc in __init__(self, data, index, columns, dtype, copy)
#     222                                  dtype=dtype, copy=copy)
#     223         elif isinstance(data, dict):
# --> 224             mgr = self._init_dict(data, index, columns, dtype=dtype)
#     225         elif isinstance(data, ma.MaskedArray):
#     226             import numpy.ma.mrecords as mrecords
#
# /Users/luinhon/anaconda/lib/python2.7/site-packages/pandas/core/frame.pyc in _init_dict(self, data, index, columns, dtype)
#     358             arrays = [data[k] for k in keys]
#     359
# --> 360         return _arrays_to_mgr(arrays, data_names, index, columns, dtype=dtype)
#     361
#     362     def _init_ndarray(self, values, index, columns, dtype=None, copy=False):
#
# /Users/luinhon/anaconda/lib/python2.7/site-packages/pandas/core/frame.pyc in _arrays_to_mgr(arrays, arr_names, index, columns, dtype)
#    5229     # figure out the index, if necessary
#    5230     if index is None:
# -> 5231         index = extract_index(arrays)
#    5232     else:
#    5233         index = _ensure_index(index)
#
# /Users/luinhon/anaconda/lib/python2.7/site-packages/pandas/core/frame.pyc in extract_index(data)
#    5280
#    5281             if have_dicts:
# -> 5282                 raise ValueError('Mixing dicts with non-Series may lead to '
#    5283                                  'ambiguous ordering.')
#    5284
#
# ValueError: Mixing dicts with non-Series may lead to ambiguous ordering.

# %% [markdown]
# Table 형태로 읽을 수 없는 JSON 파일

# %%
df = pd.read_json('donut_using_json.json')

# %%
for record in df['leagues']:
    print record
# Out:
# {u'country': u'england', u'income': 9995, u'teams': [u'liverpool', u'arsenal', u'manchester']}
# {u'country': u'spain', u'income': 12985, u'teams': [u'barcelona', u'madrid', u'atlantico']}
# {u'country': u'italy', u'income': 7128, u'teams': [u'juventus', u'ac milan', u'forgot']}

# %%
df.leagues[0]
# Out:
# {u'country': u'england',
#  u'income': 9995,
#  u'teams': [u'liverpool', u'arsenal', u'manchester']}

# %%
pd.DataFrame(df.leagues[0])
# Out:
#    country  income       teams
# 0  england    9995   liverpool
# 1  england    9995     arsenal
# 2  england    9995  manchester

# %% [markdown]
# #OpenAPI 로 가져온 데이터 파일로 저장하기

# %%
import sys
reload(sys)
sys.setdefaultencoding('utf-8')
import requests
import json
servicekey = 'oVe6oF+10r9lo1LeluHJsTCvWRr19wnrvlp0NKaZmrVUTBwevUP04ENshg23yrmpUGxuQewqLnxWKW0Gr0CArw=='
endpoint = 'http://openapi.airport.co.kr/service'

rest = '/rest/AirportCodeList/getAirportCodeList'
params = { 'serviceKey' : servicekey, 'schLineType' : 'I', '_type' : 'json', 'pageNo' : 2 }

# %%
response = requests.get(endpoint+rest, params = params)
response
# Out:
# <Response [200]>

# %%
result = response.json()

# %%
import pandas as pd
df = pd.DataFrame(result['response']['body']['items']['item'])
df
# Out:
#   cityChn cityCode     cityEng cityJpn cityKor
# 0     NaN      KUV      GUNSAN    クンサン      군산
# 1     NaN      KWJ     GWANGJU   クアンジュ      광주
# 2      蘭州      LHW     LANZHOU      蘭州     란저우
# 3      澳門      MFM       MACAU      澳門     마카오
# 4     NaN      MKO       MAKAU     NaN     마카오
# 5     NaN      MMB  MEMANBETSU   ミマンテス    메만베츠
# 6     NaN      MNL      MANILA     マニラ     마닐라
# 7     NaN      MPK       MOKPO     NaN      목포
# 8     NaN      MRO     MORIOKA     NaN    모리오카
# 9     NaN      MWX        MUAN     NaN      무안

# %%
df.to_csv('AirportCodeList.csv')

# %% [markdown]
# #CSV utf-8 저장

# %% [markdown]
# "\xEF\xBB\xBF"

# %%
file = open('AirportCodeList_utf.csv','w')
file.write('\xEF\xBB\xBF')

# %%
df.to_csv(file)

# %%
file.close()

# %% [markdown]
# #EXCEL

# %%
import pandas as pd
xlsdata = pd.read_excel('20150427_085237.xlsx',u'RAW데이터', index_col=None, na_values=['NA'])

# %%
xlsdata

# %% [markdown]
# #HTML
# lxml, html5lib 라이브러리 설치 필요

# %%
import pandas as pd
url = 'http://www.fdic.gov/bank/individual/failed/banklist.html'
dfs = pd.read_html(url)

# %%
dfs[0]

# %% [markdown]
# #cp949

# %%
import pandas as pd
df = pd.read_csv('newsjelly_obesity_BMI.csv', encoding='cp949', skiprows=1, index_col=0)

# %%
df

# %%
import sys
reload(sys)
sys.setdefaultencoding('utf-8')
